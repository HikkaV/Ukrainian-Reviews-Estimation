# %%
#!pip install stop-words

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("processed_data.csv")
# Out:
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
from ast import literal_eval

df["review_translate_sentences_lemma"] = df.apply(lambda row: " ".join(literal_eval(row["review_translate_sentences_lemma"])[0]), axis=1 )

# %%
df['dataset_name'].value_counts()
# Out:
# rozetka                            391784
# tripadvisor_restaurants_ukraine    191191
# tripadvisor_hotels_ukraine          79932
# Name: dataset_name, dtype: int64

# %%
df.head()
# Out:
#                                               review  \
# 0          Якісна пластмаса, переворот 360 градусвв
# 1                        За такі гроші це самий топ
# 2         За такі гроші - просто супер! Рекомендую.
# 3  Виконує свою роботу не погано.але що ви хотіли...
# 4  Купляв на стару сістему як основний під віндов...
#
#                                     review_translate  rating  \
# 0          Якісна пластмаса , переворот 360 градусвв     5.0
# 1                         За такі гроші це самий топ     5.0
# 2        За такі гроші - просто супер ! Рекомендую .     5.0
# 3  Виконує свою роботу не погано . але що ви хоті...     4.0
# 4  Купляв на стару сістему як основний під віндов...     4.0
#
#                 entity_name dataset_name title_translate  translated  \
# 0  screechers_wild_eu684204      rozetka             NaN       False
# 1     xiaomi_hsej03jy_black      rozetka             NaN       False
# 2          esperanza_eza108      rozetka             NaN       False
# 3                 voin_v_80      rozetka             NaN       False
# 4    kingston_sa400s37_240g      rozetka             NaN       False
#
#                           review_translate_sentences  \
# 0      ['Якісна пластмаса , переворот 360 градусвв']
# 1                     ['За такі гроші це самий топ']
# 2  ['За такі гроші - просто супер !', 'Рекомендую...
# 3  ['Виконує свою роботу не погано .', 'але що ви...
# 4  ['Купляв на стару сістему як основний під вінд...
#
#                    review_translate_sentences_tokens  \
# 0  [['Якісна', 'пластмаса', ',', 'переворот', '36...
# 1    [['За', 'такі', 'гроші', 'це', 'самий', 'топ']]
# 2  [['За', 'такі', 'гроші', '-', 'просто', 'супер...
# 3  [['Виконує', 'свою', 'роботу', 'не', 'погано',...
# 4  [['Купляв', 'на', 'стару', 'сістему', 'як', 'о...
#
#                       review_translate_sentences_pos  \
# 0  [['ADJF', 'NOUN', 'PNCT', 'NOUN', 'NUMB', 'NOU...
# 1  [['ADVB', 'NPRO', 'NOUN', 'PRCL', 'NPRO', 'UNK...
# 2  [['ADVB', 'NPRO', 'NOUN', 'PNCT', 'PRCL', 'NOU...
# 3  [['VERB', 'NPRO', 'NOUN', 'PRCL', 'NOUN', 'PNC...
# 4  [['VERB', 'INTJ', 'ADJF', 'NOUN', 'PRCL', 'ADJ...
#
#                     review_translate_sentences_lemma  \
# 0         якісний пластмаса , переворот 360 градусвв
# 1                         за такий гріш це самий топ
# 2                     за такий гріш - просто супер !
# 3                  виконувати свій робот не погана .
# 4  купляти на старий сістема як основний під вінд...
#
#                          is_question
# 0                            [False]
# 1                            [False]
# 2                     [False, False]
# 3  [False, True, True, False, False]
# 4                     [False, False]

# %%
#Note: 
df["rating"].value_counts()
# Out:
# 5.0    433247
# 4.0    108040
# 3.0     47286
# 1.0     43488
# 2.0     30846
# Name: rating, dtype: int64

# %%
train_val_test_col = pd.read_csv("train_val_test_indices.csv")

# %%
train_val_test_col["split"].value_counts()
# Out:
# train    530324
# test      66293
# val       66290
# Name: split, dtype: int64

# %%
df["train_val_test"] = train_val_test_col["split"]

# %%
df.head()
# Out:
#                                               review  \
# 0          Якісна пластмаса, переворот 360 градусвв
# 1                        За такі гроші це самий топ
# 2         За такі гроші - просто супер! Рекомендую.
# 3  Виконує свою роботу не погано.але що ви хотіли...
# 4  Купляв на стару сістему як основний під віндов...
#
#                                     review_translate  rating  \
# 0          Якісна пластмаса , переворот 360 градусвв     5.0
# 1                         За такі гроші це самий топ     5.0
# 2        За такі гроші - просто супер ! Рекомендую .     5.0
# 3  Виконує свою роботу не погано . але що ви хоті...     4.0
# 4  Купляв на стару сістему як основний під віндов...     4.0
#
#                 entity_name dataset_name title_translate  translated  \
# 0  screechers_wild_eu684204      rozetka             NaN       False
# 1     xiaomi_hsej03jy_black      rozetka             NaN       False
# 2          esperanza_eza108      rozetka             NaN       False
# 3                 voin_v_80      rozetka             NaN       False
# 4    kingston_sa400s37_240g      rozetka             NaN       False
#
#                           review_translate_sentences  \
# 0      ['Якісна пластмаса , переворот 360 градусвв']
# 1                     ['За такі гроші це самий топ']
# 2  ['За такі гроші - просто супер !', 'Рекомендую...
# 3  ['Виконує свою роботу не погано .', 'але що ви...
# 4  ['Купляв на стару сістему як основний під вінд...
#
#                    review_translate_sentences_tokens  \
# 0  [['Якісна', 'пластмаса', ',', 'переворот', '36...
# 1    [['За', 'такі', 'гроші', 'це', 'самий', 'топ']]
# 2  [['За', 'такі', 'гроші', '-', 'просто', 'супер...
# 3  [['Виконує', 'свою', 'роботу', 'не', 'погано',...
# 4  [['Купляв', 'на', 'стару', 'сістему', 'як', 'о...
#
#                       review_translate_sentences_pos  \
# 0  [['ADJF', 'NOUN', 'PNCT', 'NOUN', 'NUMB', 'NOU...
# 1  [['ADVB', 'NPRO', 'NOUN', 'PRCL', 'NPRO', 'UNK...
# 2  [['ADVB', 'NPRO', 'NOUN', 'PNCT', 'PRCL', 'NOU...
# 3  [['VERB', 'NPRO', 'NOUN', 'PRCL', 'NOUN', 'PNC...
# 4  [['VERB', 'INTJ', 'ADJF', 'NOUN', 'PRCL', 'ADJ...
#
#                     review_translate_sentences_lemma  \
# 0         якісний пластмаса , переворот 360 градусвв
# 1                         за такий гріш це самий топ
# 2                     за такий гріш - просто супер !
# 3                  виконувати свій робот не погана .
# 4  купляти на старий сістема як основний під вінд...
#
#                          is_question train_val_test
# 0                            [False]          train
# 1                            [False]           test
# 2                     [False, False]          train
# 3  [False, True, True, False, False]          train
# 4                     [False, False]          train

# %%
from stop_words import get_stop_words
from string import punctuation

ua_stop_words = get_stop_words("ukrainian")

stop_words_and_punctuation = ua_stop_words + list(punctuation)

# %%
stop_words_and_punctuation = [w if len(w) < 2 else w.replace('\'', '') for w in stop_words_and_punctuation]

# %% [markdown]
# ## bag-of-words + lemmatization, stopwords cleaning, no punctuation to tf idf vectorizer

# %%
import joblib
import os
from sklearn.metrics import confusion_matrix, f1_score
import json
import os.path


def save_model(model, model_name, data_trained):
    """
    model: pipeline instance
    model_name: string
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    """
    joblib.dump(model, 'models/' + model_name + '/' + data_trained + '_trained_model.pkl', compress = 1)
    


def get_metrics(model, data_trained, df, model_name="default"):
    """
    model: pipeline instance
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    df: full original DataFrame with all data for all websites
    model_name: default can any model but xgb cause xgb has class encoding 0,1,2,3,4 not 1,2,3,4,5
    """
    
    metrics_dict = {}
    
    if data_trained == "all_data":
        
#         X_train, y_train = train_df["review_translate_sentences_lemma"], train_df["rating"]
#         X_val, y_val = val_df["review_translate_sentences_lemma"], val_df["rating"]
#         X_test, y_test = test_df["review_translate_sentences_lemma"], val_df["rating"]
        
#         y_train_pred = model.predict(X_train)
#         y_val_pred = model.predict(X_val)

        cur_df = df
        
        
        if "predictions" in cur_df.columns:
            del cur_df["predictions"]
            
        cur_df["predictions"] = model.predict(cur_df["review_translate_sentences_lemma"])
        
        if model_name == "xgb":
            cur_df["predictions"] = cur_df["predictions"] + 1
            #cur_df["rating"] = cur_df["rating"] + 1
            
#         print("all data")
#         print(cur_df["predictions"].value_counts())

        for data_src in ["all_data", "rozetka", "tripadvisor_hotels_ukraine", "tripadvisor_restaurants_ukraine"]:
            y_train_pred = None
            y_val_pred = None
            y_test_pred = None
            y_train = None
            y_val = None
            y_test = None
            
            if data_src == "all_data":
                cur_sub_df = cur_df
            else:
                cur_sub_df = cur_df[cur_df['dataset_name'] == data_src]
                
            y_train_pred = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["predictions"]
            y_val_pred = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["predictions"]
            y_test_pred = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["predictions"]

            y_train = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["rating"]
            y_val = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["rating"]
            y_test = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["rating"]
            
            
            f1_train = f1_score(y_train_pred, y_train, average="micro")
            f1_val = f1_score(y_val_pred, y_val, average="micro")
            f1_test = f1_score(y_test_pred, y_test, average="micro")


            conf_matrix_train = confusion_matrix(y_train, y_train_pred, labels=[1,2,3,4,5])
            conf_matrix_val = confusion_matrix(y_val, y_val_pred, labels=[1,2,3,4,5])
            conf_matrix_test = confusion_matrix(y_test, y_test_pred, labels=[1,2,3,4,5])
            
            cur_metrics_dict = {
                
                "trained_on_data": data_trained,
                "evaluated_on_data": data_src,
                
                "f1_micro_train": f1_train,
                "f1_micro_val": f1_val,
                "f1_micro_test": f1_test,

                "conf_matrix_train": conf_matrix_train.tolist(),
                "conf_matrix_val": conf_matrix_val.tolist(),
                "conf_matrix_test": conf_matrix_test.tolist()

            }
            
            metrics_dict["trained_on_" + data_trained + "__eval_on_" + data_src] = cur_metrics_dict
            
    else:
        
        cur_sub_df = df[df['dataset_name'] == data_trained]
        if "predictions" in cur_sub_df.columns:
            del cur_sub_df["predictions"]
            
        cur_sub_df["predictions"] = model.predict(cur_sub_df["review_translate_sentences_lemma"])
        
        if model_name in ["xgb", "lgbm"]:
            cur_sub_df["predictions"] = cur_sub_df["predictions"] + 1
            #cur_sub_df["rating"] = cur_sub_df["rating"] + 1
        
        y_train_pred = None
        y_val_pred = None
        y_test_pred = None
        y_train = None
        y_val = None
        y_test = None

        y_train_pred = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["predictions"]
        y_val_pred = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["predictions"]
        y_test_pred = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["predictions"]

        y_train = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["rating"]
        y_val = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["rating"]
        y_test = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["rating"]
        
        


        f1_train = f1_score(y_train_pred, y_train, average="micro")
        f1_val = f1_score(y_val_pred, y_val, average="micro")
        f1_test = f1_score(y_test_pred, y_test, average="micro")


        conf_matrix_train = confusion_matrix(y_train, y_train_pred, labels=[1,2,3,4,5])
        conf_matrix_val = confusion_matrix(y_val, y_val_pred, labels=[1,2,3,4,5])
        conf_matrix_test = confusion_matrix(y_test, y_test_pred, labels=[1,2,3,4,5])
        
        cur_metrics_dict = {
                
                "trained_on_data": data_trained,
                "evaluated_on_data": data_trained,
                
                "f1_micro_train": f1_train,
                "f1_micro_val": f1_val,
                "f1_micro_test": f1_test,

                "conf_matrix_train": conf_matrix_train.tolist(),
                "conf_matrix_val": conf_matrix_val.tolist(),
                "conf_matrix_test": conf_matrix_test.tolist()

            }
        
        
        metrics_dict["trained_on_" + data_trained + "__eval_on_" + data_trained] = cur_metrics_dict
        
    
    return metrics_dict
            
        
        
def save_model_and_metrics(model, model_name, data_trained, df):
    """
    model: pipeline instance
    model_name: string
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    df: full original DataFrame with all data for all websites
    """
    
    if not os.path.exists('models/' + model_name):
        os.mkdir('models/' + model_name)
    
    save_model(model, model_name, data_trained)
    metrics = get_metrics(model, data_trained, df, model_name)
     
    with open('models/' + model_name + '/' + model_name + "_trained_on_" + data_trained + "_metrics.json", 'w') as fp:
        json.dump(metrics, fp)

# %% [markdown]
# # logistic regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import f1_score


from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args
from skopt import forest_minimize



def train_logistic_regression_model(data_trained, df, model_name):
    """
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    df: full original DataFrame with all data for all websites
    """
    
    if data_trained == "all_data":
        cur_df = df
    else:
        cur_df = df[df['dataset_name'] == data_trained]
        
    train_df = cur_df[cur_df['train_val_test'] == "train"]
    val_df = cur_df[cur_df['train_val_test'] == "val"]
    test_df = cur_df[cur_df['train_val_test'] == "test"]


    #from sklearn.ensemble import GradientBoostingRegressor
    #from sklearn.model_selection import cross_val_score


    X_train, y_train = train_df["review_translate_sentences_lemma"], train_df["rating"]
    X_val, y_val = val_df["review_translate_sentences_lemma"], val_df["rating"]
    X_test, y_test = test_df["review_translate_sentences_lemma"], val_df["rating"]

    pipeline_clf = Pipeline(
        [
            ("vect", TfidfVectorizer(stop_words=stop_words_and_punctuation)),
            ("clf", LogisticRegression(random_state=1, class_weight='balanced', multi_class='ovr', max_iter=4000, penalty="l2", tol=1e-3)),
        ]
    )

    space  = [Real(0.7, 0.95, name="vect__max_df"),
          Integer(5, 50, name="vect__min_df"),
          #Categorical(categories=[(1, 1), (1, 2)], name="vect__ngram_range", transform="string"), #TRY a different DATA TYPE ????
          Integer(1, 2, name="ngrams"),
          #Categorical(categories=['none', 'l2'], name="clf__penalty", transform="string")
          #Categorical(categories=[1000], name="clf__max_iter"),
          #Categorical(categories=["ovr"], name="clf__multi_class"),
          #Categorical(categories=[1], name="clf__random_state"),
          #Categorical(categories=['balanced'], name="clf__class_weight")
         ]
    
    @use_named_args(space)
    def objective(**params):
        print(params)

        params_modified = params.copy()
        params_modified["vect__ngram_range"] = (1, params['ngrams'])
        del params_modified['ngrams']

        print(params_modified)

        pipeline_clf.set_params(**params_modified)
        pipeline_clf.fit(X_train, y_train)

        y_val_pred = pipeline_clf.predict(X_val)
        f1_val = f1_score(y_val_pred, y_val, average="micro")


        # return negantive f1 because by minimizing it we will improve the model
        return -f1_val
    
    res_gp = forest_minimize(objective, space, n_calls=50, random_state=0, verbose=True)

    print(res_gp)
    
    
    
    with open('models/' + model_name + '/' + model_name + "_trained_on_" + data_trained + "_parameters.json", 'w') as fp:
        params = {"vect__max_df": float(res_gp['x'][0]) ,"vect__min_df": int(res_gp['x'][1]) ,"vect__ngram_range": (1, int(res_gp['x'][2]))}
        json.dump(params, fp)

    
    # refit
    pipeline_clf.set_params(**{"vect__max_df": res_gp['x'][0] ,"vect__min_df": res_gp['x'][1] ,"vect__ngram_range": (1, res_gp['x'][2])})
    pipeline_clf.fit(X_train, y_train)
    
    return pipeline_clf
    
    

logistic_regression_pipeline = None
model_name = "logistic_regression"

for data_src in ["tripadvisor_hotels_ukraine", "tripadvisor_restaurants_ukraine", "all_data", "rozetka"
                ]:
    print("Starting:")
    print(model_name + " " + data_src)
    print("\n")
    
    if not os.path.exists('models/' + model_name):
        os.mkdir('models/' + model_name)
        
    logistic_regression_pipeline = train_logistic_regression_model(data_src, df, model_name)
    save_model_and_metrics(logistic_regression_pipeline, model_name, data_src, df)
# Out:
# Starting:
# logistic_regression tripadvisor_hotels_ukraine
#
#
# Iteration No: 1 started. Evaluating function at random point.
# {'vect__max_df': 0.8482111545562545, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8482111545562545, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:401: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ласка', 'разу'] not in stop_words.
#   % sorted(inconsistent)
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 4.0463
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 2 started. Evaluating function at random point.
# {'vect__max_df': 0.9144864044056892, 'vect__min_df': 44, 'ngrams': 2}
# {'vect__max_df': 0.9144864044056892, 'vect__min_df': 44, 'vect__ngram_range': (1, 2)}
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 2.9015
# Function value obtained: -0.4569
# Current minimum: -0.4861
# Iteration No: 3 started. Evaluating function at random point.
# {'vect__max_df': 0.855890924196493, 'vect__min_df': 41, 'ngrams': 2}
# {'vect__max_df': 0.855890924196493, 'vect__min_df': 41, 'vect__ngram_range': (1, 2)}
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 3.0540
# Function value obtained: -0.4575
# Current minimum: -0.4861
# Iteration No: 4 started. Evaluating function at random point.
# {'vect__max_df': 0.9229432501955199, 'vect__min_df': 29, 'ngrams': 1}
# {'vect__max_df': 0.9229432501955199, 'vect__min_df': 29, 'vect__ngram_range': (1, 1)}
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 2.6182
# Function value obtained: -0.4608
# Current minimum: -0.4861
# Iteration No: 5 started. Evaluating function at random point.
# {'vect__max_df': 0.7958603797064444, 'vect__min_df': 43, 'ngrams': 2}
# {'vect__max_df': 0.7958603797064444, 'vect__min_df': 43, 'vect__ngram_range': (1, 2)}
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 3.1480
# Function value obtained: -0.4573
# Current minimum: -0.4861
# Iteration No: 6 started. Evaluating function at random point.
# {'vect__max_df': 0.8322237299382261, 'vect__min_df': 29, 'ngrams': 2}
# {'vect__max_df': 0.8322237299382261, 'vect__min_df': 29, 'vect__ngram_range': (1, 2)}
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 2.9530
# Function value obtained: -0.4588
# Current minimum: -0.4861
# Iteration No: 7 started. Evaluating function at random point.
# {'vect__max_df': 0.9313991595731652, 'vect__min_df': 18, 'ngrams': 1}
# {'vect__max_df': 0.9313991595731652, 'vect__min_df': 18, 'vect__ngram_range': (1, 1)}
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 2.7888
# Function value obtained: -0.4644
# Current minimum: -0.4861
# Iteration No: 8 started. Evaluating function at random point.
# {'vect__max_df': 0.7217823249253852, 'vect__min_df': 21, 'ngrams': 2}
# {'vect__max_df': 0.7217823249253852, 'vect__min_df': 21, 'vect__ngram_range': (1, 2)}
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 3.4513
# Function value obtained: -0.4662
# Current minimum: -0.4861
# Iteration No: 9 started. Evaluating function at random point.
# {'vect__max_df': 0.9392887897382616, 'vect__min_df': 20, 'ngrams': 2}
# {'vect__max_df': 0.9392887897382616, 'vect__min_df': 20, 'vect__ngram_range': (1, 2)}
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 3.3540
# Function value obtained: -0.4680
# Current minimum: -0.4861
# Iteration No: 10 started. Evaluating function at random point.
# {'vect__max_df': 0.9175218145896091, 'vect__min_df': 40, 'ngrams': 1}
# {'vect__max_df': 0.9175218145896091, 'vect__min_df': 40, 'vect__ngram_range': (1, 1)}
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 2.4491
# Function value obtained: -0.4584
# Current minimum: -0.4861
# Iteration No: 11 started. Searching for the next optimal point.
# {'vect__max_df': 0.8517612652791129, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8517612652791129, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 4.2408
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 12 started. Searching for the next optimal point.
# {'vect__max_df': 0.8497630301645398, 'vect__min_df': 13, 'ngrams': 2}
# {'vect__max_df': 0.8497630301645398, 'vect__min_df': 13, 'vect__ngram_range': (1, 2)}
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 3.4896
# Function value obtained: -0.4719
# Current minimum: -0.4861
# Iteration No: 13 started. Searching for the next optimal point.
# {'vect__max_df': 0.8370372161244534, 'vect__min_df': 9, 'ngrams': 2}
# {'vect__max_df': 0.8370372161244534, 'vect__min_df': 9, 'vect__ngram_range': (1, 2)}
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 3.9812
# Function value obtained: -0.4774
# Current minimum: -0.4861
# Iteration No: 14 started. Searching for the next optimal point.
# {'vect__max_df': 0.8478823433619171, 'vect__min_df': 8, 'ngrams': 1}
# {'vect__max_df': 0.8478823433619171, 'vect__min_df': 8, 'vect__ngram_range': (1, 1)}
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 3.6008
# Function value obtained: -0.4662
# Current minimum: -0.4861
# Iteration No: 15 started. Searching for the next optimal point.
# {'vect__max_df': 0.9052400222011413, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9052400222011413, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 4.1831
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 16 started. Searching for the next optimal point.
# {'vect__max_df': 0.9429007870244286, 'vect__min_df': 5, 'ngrams': 1}
# {'vect__max_df': 0.9429007870244286, 'vect__min_df': 5, 'vect__ngram_range': (1, 1)}
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 3.6894
# Function value obtained: -0.4693
# Current minimum: -0.4861
# Iteration No: 17 started. Searching for the next optimal point.
# {'vect__max_df': 0.9072930709627779, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9072930709627779, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 4.2074
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 18 started. Searching for the next optimal point.
# {'vect__max_df': 0.9140901329701583, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.9140901329701583, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 4.3326
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 19 started. Searching for the next optimal point.
# {'vect__max_df': 0.9394296675506675, 'vect__min_df': 5, 'ngrams': 1}
# {'vect__max_df': 0.9394296675506675, 'vect__min_df': 5, 'vect__ngram_range': (1, 1)}
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 3.7113
# Function value obtained: -0.4693
# Current minimum: -0.4861
# Iteration No: 20 started. Searching for the next optimal point.
# {'vect__max_df': 0.9440503565339609, 'vect__min_df': 10, 'ngrams': 2}
# {'vect__max_df': 0.9440503565339609, 'vect__min_df': 10, 'vect__ngram_range': (1, 2)}
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 3.7079
# Function value obtained: -0.4754
# Current minimum: -0.4861
# Iteration No: 21 started. Searching for the next optimal point.
# {'vect__max_df': 0.713559177451444, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.713559177451444, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 4.3034
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 22 started. Searching for the next optimal point.
# {'vect__max_df': 0.7116132925670836, 'vect__min_df': 7, 'ngrams': 2}
# {'vect__max_df': 0.7116132925670836, 'vect__min_df': 7, 'vect__ngram_range': (1, 2)}
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 4.5927
# Function value obtained: -0.4815
# Current minimum: -0.4861
# Iteration No: 23 started. Searching for the next optimal point.
# {'vect__max_df': 0.7738417108617536, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7738417108617536, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 4.3063
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 24 started. Searching for the next optimal point.
# {'vect__max_df': 0.9206463440802322, 'vect__min_df': 7, 'ngrams': 2}
# {'vect__max_df': 0.9206463440802322, 'vect__min_df': 7, 'vect__ngram_range': (1, 2)}
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 4.6031
# Function value obtained: -0.4815
# Current minimum: -0.4861
# Iteration No: 25 started. Searching for the next optimal point.
# {'vect__max_df': 0.7560908259332328, 'vect__min_df': 15, 'ngrams': 2}
# {'vect__max_df': 0.7560908259332328, 'vect__min_df': 15, 'vect__ngram_range': (1, 2)}
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 3.8364
# Function value obtained: -0.4707
# Current minimum: -0.4861
# Iteration No: 26 started. Searching for the next optimal point.
# {'vect__max_df': 0.752208124246222, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.752208124246222, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 4.2939
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 27 started. Searching for the next optimal point.
# {'vect__max_df': 0.7600014212060066, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.7600014212060066, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 4.5292
# Function value obtained: -0.4803
# Current minimum: -0.4861
# Iteration No: 28 started. Searching for the next optimal point.
# {'vect__max_df': 0.7281729066943755, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7281729066943755, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 4.1876
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 29 started. Searching for the next optimal point.
# {'vect__max_df': 0.703612319573186, 'vect__min_df': 14, 'ngrams': 2}
# {'vect__max_df': 0.703612319573186, 'vect__min_df': 14, 'vect__ngram_range': (1, 2)}
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 3.8604
# Function value obtained: -0.4697
# Current minimum: -0.4861
# Iteration No: 30 started. Searching for the next optimal point.
# {'vect__max_df': 0.7134688763480612, 'vect__min_df': 7, 'ngrams': 2}
# {'vect__max_df': 0.7134688763480612, 'vect__min_df': 7, 'vect__ngram_range': (1, 2)}
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 4.5817
# Function value obtained: -0.4815
# Current minimum: -0.4861
# Iteration No: 31 started. Searching for the next optimal point.
# {'vect__max_df': 0.9363979703782686, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9363979703782686, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 4.2474
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 32 started. Searching for the next optimal point.
# {'vect__max_df': 0.9461648690188708, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9461648690188708, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 4.2192
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 33 started. Searching for the next optimal point.
# {'vect__max_df': 0.9464825692267109, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.9464825692267109, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 4.2752
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 34 started. Searching for the next optimal point.
# {'vect__max_df': 0.9401318753394963, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9401318753394963, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 4.2386
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 35 started. Searching for the next optimal point.
# {'vect__max_df': 0.9337015183042432, 'vect__min_df': 9, 'ngrams': 2}
# {'vect__max_df': 0.9337015183042432, 'vect__min_df': 9, 'vect__ngram_range': (1, 2)}
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 4.0101
# Function value obtained: -0.4774
# Current minimum: -0.4861
# Iteration No: 36 started. Searching for the next optimal point.
# {'vect__max_df': 0.7727155679646796, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.7727155679646796, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 4.2702
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 37 started. Searching for the next optimal point.
# {'vect__max_df': 0.9384142926523409, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.9384142926523409, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 4.2864
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 38 started. Searching for the next optimal point.
# {'vect__max_df': 0.8338911743977051, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.8338911743977051, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 4.2840
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 39 started. Searching for the next optimal point.
# {'vect__max_df': 0.8362507241826264, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.8362507241826264, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 4.2870
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 40 started. Searching for the next optimal point.
# {'vect__max_df': 0.9363865345700813, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9363865345700813, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 4.2509
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 41 started. Searching for the next optimal point.
# {'vect__max_df': 0.7679492092391279, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.7679492092391279, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 4.2812
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 42 started. Searching for the next optimal point.
# {'vect__max_df': 0.8334537030665352, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.8334537030665352, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 4.5395
# Function value obtained: -0.4803
# Current minimum: -0.4861
# Iteration No: 43 started. Searching for the next optimal point.
# {'vect__max_df': 0.8339697453194225, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.8339697453194225, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 4.2726
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 44 started. Searching for the next optimal point.
# {'vect__max_df': 0.7804451571662487, 'vect__min_df': 11, 'ngrams': 2}
# {'vect__max_df': 0.7804451571662487, 'vect__min_df': 11, 'vect__ngram_range': (1, 2)}
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 3.9397
# Function value obtained: -0.4743
# Current minimum: -0.4861
# Iteration No: 45 started. Searching for the next optimal point.
# {'vect__max_df': 0.9412675071013428, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9412675071013428, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 4.3126
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 46 started. Searching for the next optimal point.
# {'vect__max_df': 0.9410304540523212, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9410304540523212, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 4.1958
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 47 started. Searching for the next optimal point.
# {'vect__max_df': 0.9002504404818277, 'vect__min_df': 17, 'ngrams': 2}
# {'vect__max_df': 0.9002504404818277, 'vect__min_df': 17, 'vect__ngram_range': (1, 2)}
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 3.4426
# Function value obtained: -0.4678
# Current minimum: -0.4861
# Iteration No: 48 started. Searching for the next optimal point.
# {'vect__max_df': 0.9438543934240871, 'vect__min_df': 11, 'ngrams': 2}
# {'vect__max_df': 0.9438543934240871, 'vect__min_df': 11, 'vect__ngram_range': (1, 2)}
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 3.7904
# Function value obtained: -0.4743
# Current minimum: -0.4861
# Iteration No: 49 started. Searching for the next optimal point.
# {'vect__max_df': 0.9467399721749814, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9467399721749814, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 4.5129
# Function value obtained: -0.4861
# Current minimum: -0.4861
# Iteration No: 50 started. Searching for the next optimal point.
# {'vect__max_df': 0.9446714463161048, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9446714463161048, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 4.2512
# Function value obtained: -0.4861
# Current minimum: -0.4861
#           fun: -0.48605029400725636
#     func_vals: array([-0.48605029, -0.45689979, -0.45752533, -0.46077818, -0.45727512,
#        -0.45877643, -0.46440636, -0.46615789, -0.46803453, -0.4584011 ,
#        -0.48605029, -0.47191292, -0.47741774, -0.46615789, -0.48605029,
#        -0.46928562, -0.48605029, -0.48605029, -0.46928562, -0.47541599,
#        -0.48605029, -0.48154635, -0.48605029, -0.48154635, -0.47066183,
#        -0.48605029, -0.48029526, -0.48605029, -0.46966095, -0.48154635,
#        -0.48605029, -0.48605029, -0.48605029, -0.48605029, -0.47741774,
#        -0.48605029, -0.48605029, -0.48605029, -0.48605029, -0.48605029,
#        -0.48605029, -0.48029526, -0.48605029, -0.47429   , -0.48605029,
#        -0.48605029, -0.46778431, -0.47429   , -0.48605029, -0.48605029])
#        models: [ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396)]
#  random_state: RandomState(MT19937) at 0x7F43420E4160
#         space: Space([Real(low=0.7, high=0.95, prior='uniform', transform='identity'),
#        Integer(low=5, high=50, prior='uniform', transform='identity'),
#        Integer(low=1, high=2, prior='uniform', transform='identity')])
#         specs: {'args': {'func': <function train_logistic_regression_model.<locals>.objective at 0x7f42e013c5f0>, 'dimensions': [Real(low=0.7, high=0.95, prior='uniform', transform='identity'), Integer(low=5, high=50, prior='uniform', transform='identity'), Integer(low=1, high=2, prior='uniform', transform='identity')], 'base_estimator': 'ET', 'n_calls': 50, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'EI', 'acq_optimizer': 'sampling', 'x0': None, 'y0': None, 'random_state': 0, 'verbose': True, 'callback': None, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#             x: [0.8482111545562545, 5, 2]
#       x_iters: [[0.8482111545562545, 5, 2], [0.9144864044056892, 44, 2], [0.855890924196493, 41, 2], [0.9229432501955199, 29, 1], [0.7958603797064444, 43, 2], [0.8322237299382261, 29, 2], [0.9313991595731652, 18, 1], [0.7217823249253852, 21, 2], [0.9392887897382616, 20, 2], [0.9175218145896091, 40, 1], [0.8517612652791129, 5, 2], [0.8497630301645398, 13, 2], [0.8370372161244534, 9, 2], [0.8478823433619171, 8, 1], [0.9052400222011413, 5, 2], [0.9429007870244286, 5, 1], [0.9072930709627779, 5, 2], [0.9140901329701583, 6, 2], [0.9394296675506675, 5, 1], [0.9440503565339609, 10, 2], [0.713559177451444, 6, 2], [0.7116132925670836, 7, 2], [0.7738417108617536, 5, 2], [0.9206463440802322, 7, 2], [0.7560908259332328, 15, 2], [0.752208124246222, 6, 2], [0.7600014212060066, 8, 2], [0.7281729066943755, 5, 2], [0.703612319573186, 14, 2], [0.7134688763480612, 7, 2], [0.9363979703782686, 5, 2], [0.9461648690188708, 5, 2], [0.9464825692267109, 6, 2], [0.9401318753394963, 5, 2], [0.9337015183042432, 9, 2], [0.7727155679646796, 6, 2], [0.9384142926523409, 6, 2], [0.8338911743977051, 6, 2], [0.8362507241826264, 6, 2], [0.9363865345700813, 5, 2], [0.7679492092391279, 6, 2], [0.8334537030665352, 8, 2], [0.8339697453194225, 6, 2], [0.7804451571662487, 11, 2], [0.9412675071013428, 5, 2], [0.9410304540523212, 5, 2], [0.9002504404818277, 17, 2], [0.9438543934240871, 11, 2], [0.9467399721749814, 5, 2], [0.9446714463161048, 5, 2]]
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Starting:
# logistic_regression tripadvisor_restaurants_ukraine
#
#
# Iteration No: 1 started. Evaluating function at random point.
# {'vect__max_df': 0.8482111545562545, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8482111545562545, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:401: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ласка', 'разу'] not in stop_words.
#   % sorted(inconsistent)
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 10.7137
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 2 started. Evaluating function at random point.
# {'vect__max_df': 0.9144864044056892, 'vect__min_df': 44, 'ngrams': 2}
# {'vect__max_df': 0.9144864044056892, 'vect__min_df': 44, 'vect__ngram_range': (1, 2)}
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 8.9524
# Function value obtained: -0.4910
# Current minimum: -0.5073
# Iteration No: 3 started. Evaluating function at random point.
# {'vect__max_df': 0.855890924196493, 'vect__min_df': 41, 'ngrams': 2}
# {'vect__max_df': 0.855890924196493, 'vect__min_df': 41, 'vect__ngram_range': (1, 2)}
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 8.6099
# Function value obtained: -0.4922
# Current minimum: -0.5073
# Iteration No: 4 started. Evaluating function at random point.
# {'vect__max_df': 0.9229432501955199, 'vect__min_df': 29, 'ngrams': 1}
# {'vect__max_df': 0.9229432501955199, 'vect__min_df': 29, 'vect__ngram_range': (1, 1)}
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 7.0732
# Function value obtained: -0.4937
# Current minimum: -0.5073
# Iteration No: 5 started. Evaluating function at random point.
# {'vect__max_df': 0.7958603797064444, 'vect__min_df': 43, 'ngrams': 2}
# {'vect__max_df': 0.7958603797064444, 'vect__min_df': 43, 'vect__ngram_range': (1, 2)}
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 8.3441
# Function value obtained: -0.4910
# Current minimum: -0.5073
# Iteration No: 6 started. Evaluating function at random point.
# {'vect__max_df': 0.8322237299382261, 'vect__min_df': 29, 'ngrams': 2}
# {'vect__max_df': 0.8322237299382261, 'vect__min_df': 29, 'vect__ngram_range': (1, 2)}
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 8.9640
# Function value obtained: -0.4929
# Current minimum: -0.5073
# Iteration No: 7 started. Evaluating function at random point.
# {'vect__max_df': 0.9313991595731652, 'vect__min_df': 18, 'ngrams': 1}
# {'vect__max_df': 0.9313991595731652, 'vect__min_df': 18, 'vect__ngram_range': (1, 1)}
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 7.9655
# Function value obtained: -0.4961
# Current minimum: -0.5073
# Iteration No: 8 started. Evaluating function at random point.
# {'vect__max_df': 0.7217823249253852, 'vect__min_df': 21, 'ngrams': 2}
# {'vect__max_df': 0.7217823249253852, 'vect__min_df': 21, 'vect__ngram_range': (1, 2)}
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 9.3572
# Function value obtained: -0.4961
# Current minimum: -0.5073
# Iteration No: 9 started. Evaluating function at random point.
# {'vect__max_df': 0.9392887897382616, 'vect__min_df': 20, 'ngrams': 2}
# {'vect__max_df': 0.9392887897382616, 'vect__min_df': 20, 'vect__ngram_range': (1, 2)}
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 10.0783
# Function value obtained: -0.4962
# Current minimum: -0.5073
# Iteration No: 10 started. Evaluating function at random point.
# {'vect__max_df': 0.9175218145896091, 'vect__min_df': 40, 'ngrams': 1}
# {'vect__max_df': 0.9175218145896091, 'vect__min_df': 40, 'vect__ngram_range': (1, 1)}
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 8.2419
# Function value obtained: -0.4911
# Current minimum: -0.5073
# Iteration No: 11 started. Searching for the next optimal point.
# {'vect__max_df': 0.8517612652791129, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8517612652791129, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 11.4951
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 12 started. Searching for the next optimal point.
# {'vect__max_df': 0.8497630301645398, 'vect__min_df': 13, 'ngrams': 2}
# {'vect__max_df': 0.8497630301645398, 'vect__min_df': 13, 'vect__ngram_range': (1, 2)}
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 12.0679
# Function value obtained: -0.4981
# Current minimum: -0.5073
# Iteration No: 13 started. Searching for the next optimal point.
# {'vect__max_df': 0.8370372161244534, 'vect__min_df': 9, 'ngrams': 2}
# {'vect__max_df': 0.8370372161244534, 'vect__min_df': 9, 'vect__ngram_range': (1, 2)}
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 11.5224
# Function value obtained: -0.5025
# Current minimum: -0.5073
# Iteration No: 14 started. Searching for the next optimal point.
# {'vect__max_df': 0.8478823433619171, 'vect__min_df': 8, 'ngrams': 1}
# {'vect__max_df': 0.8478823433619171, 'vect__min_df': 8, 'vect__ngram_range': (1, 1)}
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 9.6877
# Function value obtained: -0.4991
# Current minimum: -0.5073
# Iteration No: 15 started. Searching for the next optimal point.
# {'vect__max_df': 0.9052400222011413, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9052400222011413, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 11.2131
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 16 started. Searching for the next optimal point.
# {'vect__max_df': 0.9429007870244286, 'vect__min_df': 5, 'ngrams': 1}
# {'vect__max_df': 0.9429007870244286, 'vect__min_df': 5, 'vect__ngram_range': (1, 1)}
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 10.1911
# Function value obtained: -0.4997
# Current minimum: -0.5073
# Iteration No: 17 started. Searching for the next optimal point.
# {'vect__max_df': 0.8278195153806222, 'vect__min_df': 5, 'ngrams': 1}
# {'vect__max_df': 0.8278195153806222, 'vect__min_df': 5, 'vect__ngram_range': (1, 1)}
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 10.4727
# Function value obtained: -0.4997
# Current minimum: -0.5073
# Iteration No: 18 started. Searching for the next optimal point.
# {'vect__max_df': 0.9238769651434418, 'vect__min_df': 9, 'ngrams': 2}
# {'vect__max_df': 0.9238769651434418, 'vect__min_df': 9, 'vect__ngram_range': (1, 2)}
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 11.8044
# Function value obtained: -0.5025
# Current minimum: -0.5073
# Iteration No: 19 started. Searching for the next optimal point.
# {'vect__max_df': 0.9243586654118978, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.9243586654118978, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 10.2953
# Function value obtained: -0.5038
# Current minimum: -0.5073
# Iteration No: 20 started. Searching for the next optimal point.
# {'vect__max_df': 0.7320137013240402, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7320137013240402, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 11.1806
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 21 started. Searching for the next optimal point.
# {'vect__max_df': 0.8239053986360605, 'vect__min_df': 7, 'ngrams': 2}
# {'vect__max_df': 0.8239053986360605, 'vect__min_df': 7, 'vect__ngram_range': (1, 2)}
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 12.1237
# Function value obtained: -0.5056
# Current minimum: -0.5073
# Iteration No: 22 started. Searching for the next optimal point.
# {'vect__max_df': 0.8588463926890164, 'vect__min_df': 14, 'ngrams': 2}
# {'vect__max_df': 0.8588463926890164, 'vect__min_df': 14, 'vect__ngram_range': (1, 2)}
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 10.3529
# Function value obtained: -0.4987
# Current minimum: -0.5073
# Iteration No: 23 started. Searching for the next optimal point.
# {'vect__max_df': 0.813093173054855, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.813093173054855, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 10.0001
# Function value obtained: -0.5038
# Current minimum: -0.5073
# Iteration No: 24 started. Searching for the next optimal point.
# {'vect__max_df': 0.8440133506345706, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8440133506345706, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 12.8664
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 25 started. Searching for the next optimal point.
# {'vect__max_df': 0.8386108543310883, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8386108543310883, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 11.5116
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 26 started. Searching for the next optimal point.
# {'vect__max_df': 0.8193578942612155, 'vect__min_df': 10, 'ngrams': 2}
# {'vect__max_df': 0.8193578942612155, 'vect__min_df': 10, 'vect__ngram_range': (1, 2)}
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 11.5074
# Function value obtained: -0.5004
# Current minimum: -0.5073
# Iteration No: 27 started. Searching for the next optimal point.
# {'vect__max_df': 0.7674053189429582, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7674053189429582, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 11.2225
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 28 started. Searching for the next optimal point.
# {'vect__max_df': 0.9456290824529778, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9456290824529778, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 11.2544
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 29 started. Searching for the next optimal point.
# {'vect__max_df': 0.7617123465158789, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7617123465158789, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 11.2439
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 30 started. Searching for the next optimal point.
# {'vect__max_df': 0.751664311357167, 'vect__min_df': 7, 'ngrams': 2}
# {'vect__max_df': 0.751664311357167, 'vect__min_df': 7, 'vect__ngram_range': (1, 2)}
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 11.3775
# Function value obtained: -0.5056
# Current minimum: -0.5073
# Iteration No: 31 started. Searching for the next optimal point.
# {'vect__max_df': 0.7484674525052578, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.7484674525052578, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 11.1875
# Function value obtained: -0.5050
# Current minimum: -0.5073
# Iteration No: 32 started. Searching for the next optimal point.
# {'vect__max_df': 0.7616394981796353, 'vect__min_df': 12, 'ngrams': 2}
# {'vect__max_df': 0.7616394981796353, 'vect__min_df': 12, 'vect__ngram_range': (1, 2)}
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 10.1532
# Function value obtained: -0.4993
# Current minimum: -0.5073
# Iteration No: 33 started. Searching for the next optimal point.
# {'vect__max_df': 0.7021880332483947, 'vect__min_df': 5, 'ngrams': 1}
# {'vect__max_df': 0.7021880332483947, 'vect__min_df': 5, 'vect__ngram_range': (1, 1)}
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 10.2537
# Function value obtained: -0.4997
# Current minimum: -0.5073
# Iteration No: 34 started. Searching for the next optimal point.
# {'vect__max_df': 0.9142071417323272, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.9142071417323272, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 10.8039
# Function value obtained: -0.5050
# Current minimum: -0.5073
# Iteration No: 35 started. Searching for the next optimal point.
# {'vect__max_df': 0.9134040250583108, 'vect__min_df': 10, 'ngrams': 2}
# {'vect__max_df': 0.9134040250583108, 'vect__min_df': 10, 'vect__ngram_range': (1, 2)}
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 11.5770
# Function value obtained: -0.5004
# Current minimum: -0.5073
# Iteration No: 36 started. Searching for the next optimal point.
# {'vect__max_df': 0.8445185188864072, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.8445185188864072, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 11.0879
# Function value obtained: -0.5050
# Current minimum: -0.5073
# Iteration No: 37 started. Searching for the next optimal point.
# {'vect__max_df': 0.7023751663701286, 'vect__min_df': 9, 'ngrams': 2}
# {'vect__max_df': 0.7023751663701286, 'vect__min_df': 9, 'vect__ngram_range': (1, 2)}
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 11.4241
# Function value obtained: -0.5025
# Current minimum: -0.5073
# Iteration No: 38 started. Searching for the next optimal point.
# {'vect__max_df': 0.7810122687121408, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.7810122687121408, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 9.8403
# Function value obtained: -0.5038
# Current minimum: -0.5073
# Iteration No: 39 started. Searching for the next optimal point.
# {'vect__max_df': 0.74734966305383, 'vect__min_df': 17, 'ngrams': 2}
# {'vect__max_df': 0.74734966305383, 'vect__min_df': 17, 'vect__ngram_range': (1, 2)}
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 9.5745
# Function value obtained: -0.4958
# Current minimum: -0.5073
# Iteration No: 40 started. Searching for the next optimal point.
# {'vect__max_df': 0.9363865345700813, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9363865345700813, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 10.8435
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 41 started. Searching for the next optimal point.
# {'vect__max_df': 0.9394108810283281, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9394108810283281, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 10.8897
# Function value obtained: -0.5073
# Current minimum: -0.5073
# Iteration No: 42 started. Searching for the next optimal point.
# {'vect__max_df': 0.942088613712449, 'vect__min_df': 10, 'ngrams': 2}
# {'vect__max_df': 0.942088613712449, 'vect__min_df': 10, 'vect__ngram_range': (1, 2)}
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 11.2081
# Function value obtained: -0.5004
# Current minimum: -0.5073
# Iteration No: 43 started. Searching for the next optimal point.
# {'vect__max_df': 0.9476686427922766, 'vect__min_df': 7, 'ngrams': 2}
# {'vect__max_df': 0.9476686427922766, 'vect__min_df': 7, 'vect__ngram_range': (1, 2)}
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 10.8918
# Function value obtained: -0.5056
# Current minimum: -0.5073
# Iteration No: 44 started. Searching for the next optimal point.
# {'vect__max_df': 0.9421942602780425, 'vect__min_df': 13, 'ngrams': 2}
# {'vect__max_df': 0.9421942602780425, 'vect__min_df': 13, 'vect__ngram_range': (1, 2)}
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 11.5665
# Function value obtained: -0.4981
# Current minimum: -0.5073
# Iteration No: 45 started. Searching for the next optimal point.
# {'vect__max_df': 0.8935931799144465, 'vect__min_df': 8, 'ngrams': 1}
# {'vect__max_df': 0.8935931799144465, 'vect__min_df': 8, 'vect__ngram_range': (1, 1)}
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 9.5075
# Function value obtained: -0.4991
# Current minimum: -0.5073
# Iteration No: 46 started. Searching for the next optimal point.
# {'vect__max_df': 0.9458012485361735, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.9458012485361735, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 10.6236
# Function value obtained: -0.5050
# Current minimum: -0.5073
# Iteration No: 47 started. Searching for the next optimal point.
# {'vect__max_df': 0.8564387062405108, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.8564387062405108, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 10.6314
# Function value obtained: -0.5050
# Current minimum: -0.5073
# Iteration No: 48 started. Searching for the next optimal point.
# {'vect__max_df': 0.9485540129805083, 'vect__min_df': 12, 'ngrams': 2}
# {'vect__max_df': 0.9485540129805083, 'vect__min_df': 12, 'vect__ngram_range': (1, 2)}
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 9.7996
# Function value obtained: -0.4993
# Current minimum: -0.5073
# Iteration No: 49 started. Searching for the next optimal point.
# {'vect__max_df': 0.9385376345369989, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.9385376345369989, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 10.6454
# Function value obtained: -0.5050
# Current minimum: -0.5073
# Iteration No: 50 started. Searching for the next optimal point.
# {'vect__max_df': 0.947863163908591, 'vect__min_df': 8, 'ngrams': 1}
# {'vect__max_df': 0.947863163908591, 'vect__min_df': 8, 'vect__ngram_range': (1, 1)}
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 9.3773
# Function value obtained: -0.4991
# Current minimum: -0.5073
#           fun: -0.5073487107066269
#     func_vals: array([-0.50734871, -0.49102987, -0.49223286, -0.49369737, -0.49097756,
#        -0.49286051, -0.49605105, -0.49605105, -0.49615566, -0.49108217,
#        -0.50734871, -0.4980909 , -0.50253674, -0.49908468, -0.50734871,
#        -0.49966002, -0.49966002, -0.50253674, -0.50379204, -0.50734871,
#        -0.50557038, -0.49871855, -0.50379204, -0.50734871, -0.50734871,
#        -0.50039228, -0.50734871, -0.50734871, -0.50734871, -0.50557038,
#        -0.50499503, -0.4992939 , -0.49966002, -0.50499503, -0.50039228,
#        -0.50499503, -0.50253674, -0.50379204, -0.49578953, -0.50734871,
#        -0.50734871, -0.50039228, -0.50557038, -0.4980909 , -0.49908468,
#        -0.50499503, -0.50499503, -0.4992939 , -0.50499503, -0.49908468])
#        models: [ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
# ...
# Time taken: 28.5717
# Function value obtained: -0.5576
# Current minimum: -0.5844
# Iteration No: 29 started. Searching for the next optimal point.
# {'vect__max_df': 0.7617123465158789, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7617123465158789, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 32.9104
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 30 started. Searching for the next optimal point.
# {'vect__max_df': 0.8381581237372671, 'vect__min_df': 6, 'ngrams': 2}
# {'vect__max_df': 0.8381581237372671, 'vect__min_df': 6, 'vect__ngram_range': (1, 2)}
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 33.9293
# Function value obtained: -0.5793
# Current minimum: -0.5844
# Iteration No: 31 started. Searching for the next optimal point.
# {'vect__max_df': 0.9350205150836695, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9350205150836695, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 33.7245
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 32 started. Searching for the next optimal point.
# {'vect__max_df': 0.9396605890862539, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9396605890862539, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 32.1886
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 33 started. Searching for the next optimal point.
# {'vect__max_df': 0.9395101282077909, 'vect__min_df': 7, 'ngrams': 2}
# {'vect__max_df': 0.9395101282077909, 'vect__min_df': 7, 'vect__ngram_range': (1, 2)}
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 31.6298
# Function value obtained: -0.5763
# Current minimum: -0.5844
# Iteration No: 34 started. Searching for the next optimal point.
# {'vect__max_df': 0.8382880606657733, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8382880606657733, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 32.5711
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 35 started. Searching for the next optimal point.
# {'vect__max_df': 0.8361750069680838, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.8361750069680838, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 31.4063
# Function value obtained: -0.5725
# Current minimum: -0.5844
# Iteration No: 36 started. Searching for the next optimal point.
# {'vect__max_df': 0.9410891683401681, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.9410891683401681, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 32.4343
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 37 started. Searching for the next optimal point.
# {'vect__max_df': 0.9385854793781396, 'vect__min_df': 9, 'ngrams': 2}
# {'vect__max_df': 0.9385854793781396, 'vect__min_df': 9, 'vect__ngram_range': (1, 2)}
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 30.3121
# Function value obtained: -0.5694
# Current minimum: -0.5844
# Iteration No: 38 started. Searching for the next optimal point.
# {'vect__max_df': 0.8345184130903257, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8345184130903257, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 32.3257
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 39 started. Searching for the next optimal point.
# {'vect__max_df': 0.8374980146539053, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.8374980146539053, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 32.5397
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 40 started. Searching for the next optimal point.
# {'vect__max_df': 0.7039914785478816, 'vect__min_df': 12, 'ngrams': 2}
# {'vect__max_df': 0.7039914785478816, 'vect__min_df': 12, 'vect__ngram_range': (1, 2)}
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 28.8159
# Function value obtained: -0.5576
# Current minimum: -0.5844
# Iteration No: 41 started. Searching for the next optimal point.
# {'vect__max_df': 0.7811511597495808, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7811511597495808, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 32.2919
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 42 started. Searching for the next optimal point.
# {'vect__max_df': 0.7261002681535071, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7261002681535071, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 32.0644
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 43 started. Searching for the next optimal point.
# {'vect__max_df': 0.7454626492954787, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7454626492954787, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 32.3807
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 44 started. Searching for the next optimal point.
# {'vect__max_df': 0.729886257533631, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.729886257533631, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 32.3227
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 45 started. Searching for the next optimal point.
# {'vect__max_df': 0.7287824141606638, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7287824141606638, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 32.4607
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 46 started. Searching for the next optimal point.
# {'vect__max_df': 0.7239236348790535, 'vect__min_df': 8, 'ngrams': 2}
# {'vect__max_df': 0.7239236348790535, 'vect__min_df': 8, 'vect__ngram_range': (1, 2)}
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 31.1420
# Function value obtained: -0.5725
# Current minimum: -0.5844
# Iteration No: 47 started. Searching for the next optimal point.
# {'vect__max_df': 0.7100783698921056, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7100783698921056, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 32.1287
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 48 started. Searching for the next optimal point.
# {'vect__max_df': 0.7185777584227998, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7185777584227998, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 32.3380
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 49 started. Searching for the next optimal point.
# {'vect__max_df': 0.7033194818512605, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7033194818512605, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 32.9808
# Function value obtained: -0.5844
# Current minimum: -0.5844
# Iteration No: 50 started. Searching for the next optimal point.
# {'vect__max_df': 0.7081606305973925, 'vect__min_df': 5, 'ngrams': 2}
# {'vect__max_df': 0.7081606305973925, 'vect__min_df': 5, 'vect__ngram_range': (1, 2)}
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 32.5631
# Function value obtained: -0.5844
# Current minimum: -0.5844
#           fun: -0.584435142171627
#     func_vals: array([-0.58443514, -0.53450916, -0.53535147, -0.53366685, -0.53499413,
#        -0.54369799, -0.5368319 , -0.54739905, -0.54737353, -0.53203328,
#        -0.54887947, -0.58443514, -0.56059523, -0.58443514, -0.54954311,
#        -0.58443514, -0.57930471, -0.54954311, -0.58443514, -0.57254071,
#        -0.58443514, -0.58443514, -0.54954311, -0.56059523, -0.57930471,
#        -0.57634387, -0.57634387, -0.55763439, -0.58443514, -0.57930471,
#        -0.58443514, -0.58443514, -0.57634387, -0.58443514, -0.57254071,
#        -0.58443514, -0.56937567, -0.58443514, -0.58443514, -0.55763439,
#        -0.58443514, -0.58443514, -0.58443514, -0.58443514, -0.58443514,
#        -0.57254071, -0.58443514, -0.58443514, -0.58443514, -0.58443514])
#        models: [ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396)]
#  random_state: RandomState(MT19937) at 0x7F43420E4160
#         space: Space([Real(low=0.7, high=0.95, prior='uniform', transform='identity'),
#        Integer(low=5, high=50, prior='uniform', transform='identity'),
#        Integer(low=1, high=2, prior='uniform', transform='identity')])
#         specs: {'args': {'func': <function train_logistic_regression_model.<locals>.objective at 0x7f4305ca1b90>, 'dimensions': [Real(low=0.7, high=0.95, prior='uniform', transform='identity'), Integer(low=5, high=50, prior='uniform', transform='identity'), Integer(low=1, high=2, prior='uniform', transform='identity')], 'base_estimator': 'ET', 'n_calls': 50, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'EI', 'acq_optimizer': 'sampling', 'x0': None, 'y0': None, 'random_state': 0, 'verbose': True, 'callback': None, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#             x: [0.8482111545562545, 5, 2]
#       x_iters: [[0.8482111545562545, 5, 2], [0.9144864044056892, 44, 2], [0.855890924196493, 41, 2], [0.9229432501955199, 29, 1], [0.7958603797064444, 43, 2], [0.8322237299382261, 29, 2], [0.9313991595731652, 18, 1], [0.7217823249253852, 21, 2], [0.9392887897382616, 20, 2], [0.9175218145896091, 40, 1], [0.8379540647833147, 17, 2], [0.8389231854387427, 5, 2], [0.8456174249745154, 10, 2], [0.8757528343475103, 5, 2], [0.8818452828819693, 5, 1], [0.9296601787733182, 5, 2], [0.9489894386270329, 6, 2], [0.9334959105169343, 5, 1], [0.8818730106825019, 5, 2], [0.8765763343582769, 8, 2], [0.9461529021084256, 5, 2], [0.9460573394190371, 5, 2], [0.9490571870382518, 5, 1], [0.9487877179880321, 10, 2], [0.7484119307466084, 6, 2], [0.935419458817843, 7, 2], [0.7868910530803878, 7, 2], [0.9298012466284853, 12, 2], [0.7617123465158789, 5, 2], [0.8381581237372671, 6, 2], [0.9350205150836695, 5, 2], [0.9396605890862539, 5, 2], [0.9395101282077909, 7, 2], [0.8382880606657733, 5, 2], [0.8361750069680838, 8, 2], [0.9410891683401681, 5, 2], [0.9385854793781396, 9, 2], [0.8345184130903257, 5, 2], [0.8374980146539053, 5, 2], [0.7039914785478816, 12, 2], [0.7811511597495808, 5, 2], [0.7261002681535071, 5, 2], [0.7454626492954787, 5, 2], [0.729886257533631, 5, 2], [0.7287824141606638, 5, 2], [0.7239236348790535, 8, 2], [0.7100783698921056, 5, 2], [0.7185777584227998, 5, 2], [0.7033194818512605, 5, 2], [0.7081606305973925, 5, 2]]
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:98: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
