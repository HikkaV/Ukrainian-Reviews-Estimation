# %%
#!pip install stop-words

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("processed_data.csv")
# Out:
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
from ast import literal_eval

df["review_translate_sentences_lemma"] = df.apply(lambda row: " ".join(literal_eval(row["review_translate_sentences_lemma"])[0]), axis=1 )

# %%
df['dataset_name'].value_counts()
# Out:
# rozetka                            391784
# tripadvisor_restaurants_ukraine    191191
# tripadvisor_hotels_ukraine          79932
# Name: dataset_name, dtype: int64

# %%
#Note: 
df["rating"].value_counts()
# Out:
# 5.0    433247
# 4.0    108040
# 3.0     47286
# 1.0     43488
# 2.0     30846
# Name: rating, dtype: int64

# %%
train_val_test_col = pd.read_csv("train_val_test_indices.csv")

# %%
train_val_test_col.head()
# Out:
#    index  split
# 0      0  train
# 1      1   test
# 2      2  train
# 3      3  train
# 4      4  train

# %%
train_val_test_col["split"].value_counts()
# Out:
# train    530324
# test      66293
# val       66290
# Name: split, dtype: int64

# %%
df["train_val_test"] = train_val_test_col["split"]

# %%
from stop_words import get_stop_words
from string import punctuation

ua_stop_words = get_stop_words("ukrainian")

stop_words_and_punctuation = ua_stop_words + list(punctuation)

# %%
stop_words_and_punctuation = [w if len(w) < 2 else w.replace('\'', '') for w in stop_words_and_punctuation]

# %% [markdown]
# ## bag-of-words + lemmatization, stopwords cleaning, no punctuation to tf idf vectorizer

# %%
import joblib
import os
from sklearn.metrics import confusion_matrix, f1_score
import json
import os.path


def save_model(model, model_name, data_trained):
    """
    model: pipeline instance
    model_name: string
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    """
    joblib.dump(model, 'models/' + model_name + '/' + data_trained + '_trained_model.pkl', compress = 1)
    


def get_metrics(model, data_trained, df, model_name="default"):
    """
    model: pipeline instance
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    df: full original DataFrame with all data for all websites
    model_name: default can any model but xgb cause xgb has class encoding 0,1,2,3,4 not 1,2,3,4,5
    """
    
    metrics_dict = {}
    
    if data_trained == "all_data":
        
        cur_df = df
        
        if "predictions" in cur_df.columns:
            del cur_df["predictions"]
            
        cur_df["predictions"] = model.predict(cur_df["review_translate_sentences_lemma"])
        
        if model_name == "xgb":
            cur_df["predictions"] = cur_df["predictions"] + 1
            #cur_df["rating"] = cur_df["rating"] + 1
            

        for data_src in ["all_data", "rozetka", "tripadvisor_hotels_ukraine", "tripadvisor_restaurants_ukraine"]:
            y_train_pred = None
            y_val_pred = None
            y_test_pred = None
            y_train = None
            y_val = None
            y_test = None
            
            if data_src == "all_data":
                cur_sub_df = cur_df
            else:
                cur_sub_df = cur_df[cur_df['dataset_name'] == data_src]
                
            y_train_pred = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["predictions"]
            y_val_pred = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["predictions"]
            y_test_pred = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["predictions"]

            y_train = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["rating"]
            y_val = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["rating"]
            y_test = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["rating"]
            
            
            f1_train = f1_score(y_train_pred, y_train, average="micro")
            f1_val = f1_score(y_val_pred, y_val, average="micro")
            f1_test = f1_score(y_test_pred, y_test, average="micro")


            conf_matrix_train = confusion_matrix(y_train, y_train_pred, labels=[1,2,3,4,5])
            conf_matrix_val = confusion_matrix(y_val, y_val_pred, labels=[1,2,3,4,5])
            conf_matrix_test = confusion_matrix(y_test, y_test_pred, labels=[1,2,3,4,5])
            
            cur_metrics_dict = {
                
                "trained_on_data": data_trained,
                "evaluated_on_data": data_src,
                
                "f1_micro_train": f1_train,
                "f1_micro_val": f1_val,
                "f1_micro_test": f1_test,

                "conf_matrix_train": conf_matrix_train.tolist(),
                "conf_matrix_val": conf_matrix_val.tolist(),
                "conf_matrix_test": conf_matrix_test.tolist()

            }
            
            metrics_dict["trained_on_" + data_trained + "__eval_on_" + data_src] = cur_metrics_dict
            
    else:
        
        cur_sub_df = df[df['dataset_name'] == data_trained]
        if "predictions" in cur_sub_df.columns:
            del cur_sub_df["predictions"]
            
        cur_sub_df["predictions"] = model.predict(cur_sub_df["review_translate_sentences_lemma"])
        
        if model_name in ["xgb", "lgbm"]:
            cur_sub_df["predictions"] = cur_sub_df["predictions"] + 1
            #cur_sub_df["rating"] = cur_sub_df["rating"] + 1
        
        y_train_pred = None
        y_val_pred = None
        y_test_pred = None
        y_train = None
        y_val = None
        y_test = None

        y_train_pred = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["predictions"]
        y_val_pred = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["predictions"]
        y_test_pred = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["predictions"]

        y_train = cur_sub_df[cur_sub_df['train_val_test'] == "train"]["rating"]
        y_val = cur_sub_df[cur_sub_df['train_val_test'] == "val"]["rating"]
        y_test = cur_sub_df[cur_sub_df['train_val_test'] == "test"]["rating"]
        
        


        f1_train = f1_score(y_train_pred, y_train, average="micro")
        f1_val = f1_score(y_val_pred, y_val, average="micro")
        f1_test = f1_score(y_test_pred, y_test, average="micro")


        conf_matrix_train = confusion_matrix(y_train, y_train_pred, labels=[1,2,3,4,5])
        conf_matrix_val = confusion_matrix(y_val, y_val_pred, labels=[1,2,3,4,5])
        conf_matrix_test = confusion_matrix(y_test, y_test_pred, labels=[1,2,3,4,5])
        
        cur_metrics_dict = {
                
                "trained_on_data": data_trained,
                "evaluated_on_data": data_trained,
                
                "f1_micro_train": f1_train,
                "f1_micro_val": f1_val,
                "f1_micro_test": f1_test,

                "conf_matrix_train": conf_matrix_train.tolist(),
                "conf_matrix_val": conf_matrix_val.tolist(),
                "conf_matrix_test": conf_matrix_test.tolist()

            }
        
        
        metrics_dict["trained_on_" + data_trained + "__eval_on_" + data_trained] = cur_metrics_dict
        
    
    return metrics_dict
            
        
        
def save_model_and_metrics(model, model_name, data_trained, df):
    """
    model: pipeline instance
    model_name: string
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    df: full original DataFrame with all data for all websites
    """
    
    if not os.path.exists('models/' + model_name):
        os.mkdir('models/' + model_name)
    
    save_model(model, model_name, data_trained)
    metrics = get_metrics(model, data_trained, df, model_name)
     
    with open('models/' + model_name + '/' + model_name + "_trained_on_" + data_trained + "_metrics.json", 'w') as fp:
        json.dump(metrics, fp)

# %% [markdown]
# # XGBoost

# %%
"""
Important: XGB has class encoding 0,1,2,3,4 NOT 1,2,3,4,5 
"""

# %%
import xgboost as xgb
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import f1_score


from skopt.space import Real, Integer, Categorical
from skopt.utils import use_named_args
from skopt import forest_minimize



def train_xgb_model(data_trained, df, model_name):
    """
    data_trained: string "all_data", "rozetka", "tripadvisor_hotels_ukraine" or "tripadvisor_restaurants_ukraine"
    df: full original DataFrame with all data for all websites
    """

    df_tmp = df.copy()
    # modify rating to match 0-4 encoding pattern needed for the model
    df_tmp['rating'] = df_tmp['rating'].astype(int) - 1
    
    if data_trained == "all_data":
        cur_df = df_tmp
    else:
        cur_df = df_tmp[df_tmp['dataset_name'] == data_trained]
        
    train_df = cur_df[cur_df['train_val_test'] == "train"]
    val_df = cur_df[cur_df['train_val_test'] == "val"]
    test_df = cur_df[cur_df['train_val_test'] == "test"]


    #from sklearn.ensemble import GradientBoostingRegressor
    #from sklearn.model_selection import cross_val_score


    X_train, y_train = train_df["review_translate_sentences_lemma"], train_df["rating"]
    X_val, y_val = val_df["review_translate_sentences_lemma"], val_df["rating"]
    X_test, y_test = test_df["review_translate_sentences_lemma"], val_df["rating"]

    pipeline_clf = Pipeline(
        [
            ("vect", TfidfVectorizer(stop_words=stop_words_and_punctuation)),
            ("clf", xgb.XGBClassifier(random_state=1, objective='multi:softmax', n_jobs=3))
        ]
    )

    space  = [Real(0.7, 0.95, name="vect__max_df"),
              Integer(5, 50, name="vect__min_df"),
              Integer(1, 2, name="ngrams"),
              Integer(3, 25, name="clf__max_depth"),
              Real(1, 9, name="clf__gamma"),
              Integer(40,180, name="clf__reg_alpha"),
              Real(0, 1, name="clf__reg_lambda"),
              Real(0.5,1, name="clf__colsample_bytree"),
              Integer(0,10, name="clf__min_child_weight"),
              Integer(30,300, name="clf__n_estimators")

             ]
    
    @use_named_args(space)
    def objective(**params):
        print(params)

        params_modified = params.copy()
        params_modified["vect__ngram_range"] = (1, params['ngrams'])
        del params_modified['ngrams']

        print(params_modified)

        pipeline_clf.set_params(**params_modified)
        pipeline_clf.fit(X_train, y_train)

        y_val_pred = pipeline_clf.predict(X_val)
        f1_val = f1_score(y_val_pred, y_val, average="micro")


        # return negantive f1 because by minimizing it we will improve the model
        return -f1_val
    
    res_gp = forest_minimize(objective, space, n_calls=70, random_state=0, verbose=True)

    print(res_gp)
    
    #[0.8482111545562545, 5, 2]
    
    
    params = {"vect__max_df": float(res_gp['x'][0]) ,"vect__min_df": int(res_gp['x'][1]) ,
                               "vect__ngram_range": (1, int(res_gp['x'][2])), "clf__max_depth": int(res_gp['x'][3]), 
                               "clf__gamma": float(res_gp['x'][4]), "clf__reg_alpha": int(res_gp['x'][5]),
                               "clf__reg_lambda": float(res_gp['x'][6]), "clf__colsample_bytree": float(res_gp['x'][7]),
                               "clf__min_child_weight": int(res_gp['x'][8]), "clf__n_estimators": int(res_gp['x'][9])}
    
    with open('models/' + model_name + '/' + model_name + "_trained_on_" + data_trained + "_parameters.json", 'w') as fp:
        json.dump(params, fp)

    
    # refit
    pipeline_clf.set_params(**params)
    pipeline_clf.fit(X_train, y_train)
    
    return pipeline_clf
    
    

logistic_regression_pipeline = None
model_name = "xgb"

for data_src in ["tripadvisor_hotels_ukraine", "tripadvisor_restaurants_ukraine", "all_data", "rozetka"
                ]:
    print("Starting:")
    print(model_name + " " + data_src)
    print("\n")
    
    if not os.path.exists('models/' + model_name):
        os.mkdir('models/' + model_name)
        
    pipeline = train_xgb_model(data_src, df, model_name)
    save_model_and_metrics(pipeline, model_name, data_src, df)
# Out:
# Starting:
# xgb tripadvisor_hotels_ukraine
#
#
# Iteration No: 1 started. Evaluating function at random point.
# {'vect__max_df': 0.8482111545562545, 'vect__min_df': 5, 'ngrams': 2, 'clf__max_depth': 6, 'clf__gamma': 7.778013910273005, 'clf__reg_alpha': 61, 'clf__reg_lambda': 0.38438170729269994, 'clf__colsample_bytree': 0.6487673032722362, 'clf__min_child_weight': 8, 'clf__n_estimators': 118}
# {'vect__max_df': 0.8482111545562545, 'vect__min_df': 5, 'clf__max_depth': 6, 'clf__gamma': 7.778013910273005, 'clf__reg_alpha': 61, 'clf__reg_lambda': 0.38438170729269994, 'clf__colsample_bytree': 0.6487673032722362, 'clf__min_child_weight': 8, 'clf__n_estimators': 118, 'vect__ngram_range': (1, 2)}
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 26.6071
# Function value obtained: -0.5572
# Current minimum: -0.5572
# Iteration No: 2 started. Evaluating function at random point.
# {'vect__max_df': 0.7681640736450283, 'vect__min_df': 6, 'ngrams': 1, 'clf__max_depth': 10, 'clf__gamma': 5.231159358023237, 'clf__reg_alpha': 128, 'clf__reg_lambda': 0.39278479610082984, 'clf__colsample_bytree': 0.9180393817686889, 'clf__min_child_weight': 8, 'clf__n_estimators': 295}
# {'vect__max_df': 0.7681640736450283, 'vect__min_df': 6, 'clf__max_depth': 10, 'clf__gamma': 5.231159358023237, 'clf__reg_alpha': 128, 'clf__reg_lambda': 0.39278479610082984, 'clf__colsample_bytree': 0.9180393817686889, 'clf__min_child_weight': 8, 'clf__n_estimators': 295, 'vect__ngram_range': (1, 1)}
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 67.8413
# Function value obtained: -0.5587
# Current minimum: -0.5587
# Iteration No: 3 started. Evaluating function at random point.
# {'vect__max_df': 0.8620429680127992, 'vect__min_df': 21, 'ngrams': 2, 'clf__max_depth': 8, 'clf__gamma': 7.225254007598806, 'clf__reg_alpha': 122, 'clf__reg_lambda': 0.4736080452737106, 'clf__colsample_bytree': 0.9004553759898222, 'clf__min_child_weight': 3, 'clf__n_estimators': 177}
# {'vect__max_df': 0.8620429680127992, 'vect__min_df': 21, 'clf__max_depth': 8, 'clf__gamma': 7.225254007598806, 'clf__reg_alpha': 122, 'clf__reg_lambda': 0.4736080452737106, 'clf__colsample_bytree': 0.9004553759898222, 'clf__min_child_weight': 3, 'clf__n_estimators': 177, 'vect__ngram_range': (1, 2)}
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 42.2199
# Function value obtained: -0.5561
# Current minimum: -0.5587
# Iteration No: 4 started. Evaluating function at random point.
# {'vect__max_df': 0.7295686064672333, 'vect__min_df': 37, 'ngrams': 2, 'clf__max_depth': 12, 'clf__gamma': 5.298985835592086, 'clf__reg_alpha': 72, 'clf__reg_lambda': 0.5218483217500718, 'clf__colsample_bytree': 0.7073309699952619, 'clf__min_child_weight': 3, 'clf__n_estimators': 213}
# {'vect__max_df': 0.7295686064672333, 'vect__min_df': 37, 'clf__max_depth': 12, 'clf__gamma': 5.298985835592086, 'clf__reg_alpha': 72, 'clf__reg_lambda': 0.5218483217500718, 'clf__colsample_bytree': 0.7073309699952619, 'clf__min_child_weight': 3, 'clf__n_estimators': 213, 'vect__ngram_range': (1, 2)}
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 54.6094
# Function value obtained: -0.5610
# Current minimum: -0.5610
# Iteration No: 5 started. Evaluating function at random point.
# {'vect__max_df': 0.7541375886060929, 'vect__min_df': 5, 'ngrams': 1, 'clf__max_depth': 7, 'clf__gamma': 5.941083976607017, 'clf__reg_alpha': 78, 'clf__reg_lambda': 0.2223213882515877, 'clf__colsample_bytree': 0.693244490562931, 'clf__min_child_weight': 4, 'clf__n_estimators': 135}
# {'vect__max_df': 0.7541375886060929, 'vect__min_df': 5, 'clf__max_depth': 7, 'clf__gamma': 5.941083976607017, 'clf__reg_alpha': 78, 'clf__reg_lambda': 0.2223213882515877, 'clf__colsample_bytree': 0.693244490562931, 'clf__min_child_weight': 4, 'clf__n_estimators': 135, 'vect__ngram_range': (1, 1)}
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 20.0415
# Function value obtained: -0.5586
# Current minimum: -0.5610
# Iteration No: 6 started. Evaluating function at random point.
# {'vect__max_df': 0.8124874974778069, 'vect__min_df': 36, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 6.58104956741812, 'clf__reg_alpha': 97, 'clf__reg_lambda': 0.6667667154456678, 'clf__colsample_bytree': 0.8353189348090797, 'clf__min_child_weight': 2, 'clf__n_estimators': 121}
# {'vect__max_df': 0.8124874974778069, 'vect__min_df': 36, 'clf__max_depth': 4, 'clf__gamma': 6.58104956741812, 'clf__reg_alpha': 97, 'clf__reg_lambda': 0.6667667154456678, 'clf__colsample_bytree': 0.8353189348090797, 'clf__min_child_weight': 2, 'clf__n_estimators': 121, 'vect__ngram_range': (1, 1)}
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 12.0582
# Function value obtained: -0.5532
# Current minimum: -0.5610
# Iteration No: 7 started. Evaluating function at random point.
# {'vect__max_df': 0.8876715353046141, 'vect__min_df': 40, 'ngrams': 2, 'clf__max_depth': 15, 'clf__gamma': 5.561574163343038, 'clf__reg_alpha': 124, 'clf__reg_lambda': 0.6342740579573352, 'clf__colsample_bytree': 0.9794746343122602, 'clf__min_child_weight': 4, 'clf__n_estimators': 161}
# {'vect__max_df': 0.8876715353046141, 'vect__min_df': 40, 'clf__max_depth': 15, 'clf__gamma': 5.561574163343038, 'clf__reg_alpha': 124, 'clf__reg_lambda': 0.6342740579573352, 'clf__colsample_bytree': 0.9794746343122602, 'clf__min_child_weight': 4, 'clf__n_estimators': 161, 'vect__ngram_range': (1, 2)}
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 64.1660
# Function value obtained: -0.5589
# Current minimum: -0.5610
# Iteration No: 8 started. Evaluating function at random point.
# {'vect__max_df': 0.948824891919472, 'vect__min_df': 45, 'ngrams': 1, 'clf__max_depth': 18, 'clf__gamma': 4.797580018307304, 'clf__reg_alpha': 63, 'clf__reg_lambda': 0.3380076148388918, 'clf__colsample_bytree': 0.8373761611295104, 'clf__min_child_weight': 0, 'clf__n_estimators': 99}
# {'vect__max_df': 0.948824891919472, 'vect__min_df': 45, 'clf__max_depth': 18, 'clf__gamma': 4.797580018307304, 'clf__reg_alpha': 63, 'clf__reg_lambda': 0.3380076148388918, 'clf__colsample_bytree': 0.8373761611295104, 'clf__min_child_weight': 0, 'clf__n_estimators': 99, 'vect__ngram_range': (1, 1)}
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 38.5230
# Function value obtained: -0.5616
# Current minimum: -0.5616
# Iteration No: 9 started. Evaluating function at random point.
# {'vect__max_df': 0.7491455904200134, 'vect__min_df': 5, 'ngrams': 2, 'clf__max_depth': 8, 'clf__gamma': 1.1085730848968787, 'clf__reg_alpha': 153, 'clf__reg_lambda': 0.8379449074988041, 'clf__colsample_bytree': 0.5480492039469815, 'clf__min_child_weight': 3, 'clf__n_estimators': 128}
# {'vect__max_df': 0.7491455904200134, 'vect__min_df': 5, 'clf__max_depth': 8, 'clf__gamma': 1.1085730848968787, 'clf__reg_alpha': 153, 'clf__reg_lambda': 0.8379449074988041, 'clf__colsample_bytree': 0.5480492039469815, 'clf__min_child_weight': 3, 'clf__n_estimators': 128, 'vect__ngram_range': (1, 2)}
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 14.2923
# Function value obtained: -0.5564
# Current minimum: -0.5616
# Iteration No: 10 started. Evaluating function at random point.
# {'vect__max_df': 0.827406094179975, 'vect__min_df': 44, 'ngrams': 2, 'clf__max_depth': 12, 'clf__gamma': 1.15990132327007, 'clf__reg_alpha': 178, 'clf__reg_lambda': 0.28280696257640964, 'clf__colsample_bytree': 0.5600982806065845, 'clf__min_child_weight': 7, 'clf__n_estimators': 217}
# {'vect__max_df': 0.827406094179975, 'vect__min_df': 44, 'clf__max_depth': 12, 'clf__gamma': 1.15990132327007, 'clf__reg_alpha': 178, 'clf__reg_lambda': 0.28280696257640964, 'clf__colsample_bytree': 0.5600982806065845, 'clf__min_child_weight': 7, 'clf__n_estimators': 217, 'vect__ngram_range': (1, 2)}
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 18.9047
# Function value obtained: -0.5581
# Current minimum: -0.5616
# Iteration No: 11 started. Searching for the next optimal point.
# {'vect__max_df': 0.8704194944619559, 'vect__min_df': 44, 'ngrams': 1, 'clf__max_depth': 20, 'clf__gamma': 6.7366934680545265, 'clf__reg_alpha': 74, 'clf__reg_lambda': 0.9615070684400219, 'clf__colsample_bytree': 0.790279597567833, 'clf__min_child_weight': 10, 'clf__n_estimators': 63}
# {'vect__max_df': 0.8704194944619559, 'vect__min_df': 44, 'clf__max_depth': 20, 'clf__gamma': 6.7366934680545265, 'clf__reg_alpha': 74, 'clf__reg_lambda': 0.9615070684400219, 'clf__colsample_bytree': 0.790279597567833, 'clf__min_child_weight': 10, 'clf__n_estimators': 63, 'vect__ngram_range': (1, 1)}
# Iteration No: 11 ended. Search finished for the next optimal point.
# Time taken: 21.0237
# Function value obtained: -0.5610
# Current minimum: -0.5616
# Iteration No: 12 started. Searching for the next optimal point.
# {'vect__max_df': 0.814925020860342, 'vect__min_df': 33, 'ngrams': 1, 'clf__max_depth': 10, 'clf__gamma': 6.767455436935602, 'clf__reg_alpha': 66, 'clf__reg_lambda': 0.905949695527239, 'clf__colsample_bytree': 0.7413145415601301, 'clf__min_child_weight': 3, 'clf__n_estimators': 36}
# {'vect__max_df': 0.814925020860342, 'vect__min_df': 33, 'clf__max_depth': 10, 'clf__gamma': 6.767455436935602, 'clf__reg_alpha': 66, 'clf__reg_lambda': 0.905949695527239, 'clf__colsample_bytree': 0.7413145415601301, 'clf__min_child_weight': 3, 'clf__n_estimators': 36, 'vect__ngram_range': (1, 1)}
# Iteration No: 12 ended. Search finished for the next optimal point.
# Time taken: 7.6783
# Function value obtained: -0.5589
# Current minimum: -0.5616
# Iteration No: 13 started. Searching for the next optimal point.
# {'vect__max_df': 0.924429655972101, 'vect__min_df': 39, 'ngrams': 1, 'clf__max_depth': 5, 'clf__gamma': 2.3832447671506616, 'clf__reg_alpha': 62, 'clf__reg_lambda': 0.7805724041212783, 'clf__colsample_bytree': 0.8884039084960658, 'clf__min_child_weight': 3, 'clf__n_estimators': 96}
# {'vect__max_df': 0.924429655972101, 'vect__min_df': 39, 'clf__max_depth': 5, 'clf__gamma': 2.3832447671506616, 'clf__reg_alpha': 62, 'clf__reg_lambda': 0.7805724041212783, 'clf__colsample_bytree': 0.8884039084960658, 'clf__min_child_weight': 3, 'clf__n_estimators': 96, 'vect__ngram_range': (1, 1)}
# Iteration No: 13 ended. Search finished for the next optimal point.
# Time taken: 11.7506
# Function value obtained: -0.5604
# Current minimum: -0.5616
# Iteration No: 14 started. Searching for the next optimal point.
# {'vect__max_df': 0.869411778626388, 'vect__min_df': 50, 'ngrams': 1, 'clf__max_depth': 5, 'clf__gamma': 5.203477307173975, 'clf__reg_alpha': 85, 'clf__reg_lambda': 0.95987363247585, 'clf__colsample_bytree': 0.7999696691725029, 'clf__min_child_weight': 0, 'clf__n_estimators': 251}
# {'vect__max_df': 0.869411778626388, 'vect__min_df': 50, 'clf__max_depth': 5, 'clf__gamma': 5.203477307173975, 'clf__reg_alpha': 85, 'clf__reg_lambda': 0.95987363247585, 'clf__colsample_bytree': 0.7999696691725029, 'clf__min_child_weight': 0, 'clf__n_estimators': 251, 'vect__ngram_range': (1, 1)}
# Iteration No: 14 ended. Search finished for the next optimal point.
# Time taken: 28.5411
# Function value obtained: -0.5579
# Current minimum: -0.5616
# Iteration No: 15 started. Searching for the next optimal point.
# {'vect__max_df': 0.797202564632295, 'vect__min_df': 39, 'ngrams': 1, 'clf__max_depth': 15, 'clf__gamma': 8.027362322590706, 'clf__reg_alpha': 113, 'clf__reg_lambda': 0.7126761483507701, 'clf__colsample_bytree': 0.8952420198970634, 'clf__min_child_weight': 3, 'clf__n_estimators': 88}
# {'vect__max_df': 0.797202564632295, 'vect__min_df': 39, 'clf__max_depth': 15, 'clf__gamma': 8.027362322590706, 'clf__reg_alpha': 113, 'clf__reg_lambda': 0.7126761483507701, 'clf__colsample_bytree': 0.8952420198970634, 'clf__min_child_weight': 3, 'clf__n_estimators': 88, 'vect__ngram_range': (1, 1)}
# Iteration No: 15 ended. Search finished for the next optimal point.
# Time taken: 28.0681
# Function value obtained: -0.5581
# Current minimum: -0.5616
# Iteration No: 16 started. Searching for the next optimal point.
# {'vect__max_df': 0.8236279591451336, 'vect__min_df': 38, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 4.602737781142348, 'clf__reg_alpha': 43, 'clf__reg_lambda': 0.7586346288362497, 'clf__colsample_bytree': 0.9704245133961622, 'clf__min_child_weight': 0, 'clf__n_estimators': 78}
# {'vect__max_df': 0.8236279591451336, 'vect__min_df': 38, 'clf__max_depth': 4, 'clf__gamma': 4.602737781142348, 'clf__reg_alpha': 43, 'clf__reg_lambda': 0.7586346288362497, 'clf__colsample_bytree': 0.9704245133961622, 'clf__min_child_weight': 0, 'clf__n_estimators': 78, 'vect__ngram_range': (1, 1)}
# Iteration No: 16 ended. Search finished for the next optimal point.
# Time taken: 9.2807
# Function value obtained: -0.5619
# Current minimum: -0.5619
# Iteration No: 17 started. Searching for the next optimal point.
# {'vect__max_df': 0.8073056317051008, 'vect__min_df': 41, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 6.266059130549797, 'clf__reg_alpha': 61, 'clf__reg_lambda': 0.6545855263470961, 'clf__colsample_bytree': 0.9903930327721242, 'clf__min_child_weight': 6, 'clf__n_estimators': 129}
# {'vect__max_df': 0.8073056317051008, 'vect__min_df': 41, 'clf__max_depth': 6, 'clf__gamma': 6.266059130549797, 'clf__reg_alpha': 61, 'clf__reg_lambda': 0.6545855263470961, 'clf__colsample_bytree': 0.9903930327721242, 'clf__min_child_weight': 6, 'clf__n_estimators': 129, 'vect__ngram_range': (1, 1)}
# Iteration No: 17 ended. Search finished for the next optimal point.
# Time taken: 19.1247
# Function value obtained: -0.5591
# Current minimum: -0.5619
# Iteration No: 18 started. Searching for the next optimal point.
# {'vect__max_df': 0.8884171175658222, 'vect__min_df': 42, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 7.835091398440918, 'clf__reg_alpha': 97, 'clf__reg_lambda': 0.654938318058397, 'clf__colsample_bytree': 0.9278298687358206, 'clf__min_child_weight': 0, 'clf__n_estimators': 107}
# {'vect__max_df': 0.8884171175658222, 'vect__min_df': 42, 'clf__max_depth': 6, 'clf__gamma': 7.835091398440918, 'clf__reg_alpha': 97, 'clf__reg_lambda': 0.654938318058397, 'clf__colsample_bytree': 0.9278298687358206, 'clf__min_child_weight': 0, 'clf__n_estimators': 107, 'vect__ngram_range': (1, 1)}
# Iteration No: 18 ended. Search finished for the next optimal point.
# Time taken: 17.1717
# Function value obtained: -0.5554
# Current minimum: -0.5619
# Iteration No: 19 started. Searching for the next optimal point.
# {'vect__max_df': 0.8270053741264247, 'vect__min_df': 38, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 1.5352766853922901, 'clf__reg_alpha': 87, 'clf__reg_lambda': 0.6137988345972855, 'clf__colsample_bytree': 0.9814669239899154, 'clf__min_child_weight': 2, 'clf__n_estimators': 70}
# {'vect__max_df': 0.8270053741264247, 'vect__min_df': 38, 'clf__max_depth': 6, 'clf__gamma': 1.5352766853922901, 'clf__reg_alpha': 87, 'clf__reg_lambda': 0.6137988345972855, 'clf__colsample_bytree': 0.9814669239899154, 'clf__min_child_weight': 2, 'clf__n_estimators': 70, 'vect__ngram_range': (1, 1)}
# Iteration No: 19 ended. Search finished for the next optimal point.
# Time taken: 10.1476
# Function value obtained: -0.5617
# Current minimum: -0.5619
# Iteration No: 20 started. Searching for the next optimal point.
# {'vect__max_df': 0.9257436758570257, 'vect__min_df': 35, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 3.0134395269521, 'clf__reg_alpha': 97, 'clf__reg_lambda': 0.2057751084862584, 'clf__colsample_bytree': 0.9598662083961231, 'clf__min_child_weight': 1, 'clf__n_estimators': 120}
# {'vect__max_df': 0.9257436758570257, 'vect__min_df': 35, 'clf__max_depth': 4, 'clf__gamma': 3.0134395269521, 'clf__reg_alpha': 97, 'clf__reg_lambda': 0.2057751084862584, 'clf__colsample_bytree': 0.9598662083961231, 'clf__min_child_weight': 1, 'clf__n_estimators': 120, 'vect__ngram_range': (1, 1)}
# Iteration No: 20 ended. Search finished for the next optimal point.
# Time taken: 13.5385
# Function value obtained: -0.5552
# Current minimum: -0.5619
# Iteration No: 21 started. Searching for the next optimal point.
# {'vect__max_df': 0.822552794462462, 'vect__min_df': 36, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 1.3552681176287775, 'clf__reg_alpha': 99, 'clf__reg_lambda': 0.6682887550482637, 'clf__colsample_bytree': 0.8203200347972164, 'clf__min_child_weight': 9, 'clf__n_estimators': 63}
# {'vect__max_df': 0.822552794462462, 'vect__min_df': 36, 'clf__max_depth': 4, 'clf__gamma': 1.3552681176287775, 'clf__reg_alpha': 99, 'clf__reg_lambda': 0.6682887550482637, 'clf__colsample_bytree': 0.8203200347972164, 'clf__min_child_weight': 9, 'clf__n_estimators': 63, 'vect__ngram_range': (1, 1)}
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 5.6757
# Function value obtained: -0.5577
# Current minimum: -0.5619
# Iteration No: 22 started. Searching for the next optimal point.
# {'vect__max_df': 0.7193133530061444, 'vect__min_df': 45, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 3.6401277348839574, 'clf__reg_alpha': 94, 'clf__reg_lambda': 0.6851644472830029, 'clf__colsample_bytree': 0.8779235549718725, 'clf__min_child_weight': 2, 'clf__n_estimators': 55}
# {'vect__max_df': 0.7193133530061444, 'vect__min_df': 45, 'clf__max_depth': 3, 'clf__gamma': 3.6401277348839574, 'clf__reg_alpha': 94, 'clf__reg_lambda': 0.6851644472830029, 'clf__colsample_bytree': 0.8779235549718725, 'clf__min_child_weight': 2, 'clf__n_estimators': 55, 'vect__ngram_range': (1, 1)}
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 4.9152
# Function value obtained: -0.5539
# Current minimum: -0.5619
# Iteration No: 23 started. Searching for the next optimal point.
# {'vect__max_df': 0.7566557337199771, 'vect__min_df': 8, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 1.635023709548884, 'clf__reg_alpha': 75, 'clf__reg_lambda': 0.8273793555385663, 'clf__colsample_bytree': 0.9781356848784108, 'clf__min_child_weight': 2, 'clf__n_estimators': 41}
# {'vect__max_df': 0.7566557337199771, 'vect__min_df': 8, 'clf__max_depth': 4, 'clf__gamma': 1.635023709548884, 'clf__reg_alpha': 75, 'clf__reg_lambda': 0.8273793555385663, 'clf__colsample_bytree': 0.9781356848784108, 'clf__min_child_weight': 2, 'clf__n_estimators': 41, 'vect__ngram_range': (1, 1)}
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 5.5389
# Function value obtained: -0.5582
# Current minimum: -0.5619
# Iteration No: 24 started. Searching for the next optimal point.
# {'vect__max_df': 0.7966423415434833, 'vect__min_df': 39, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 2.0519930730300215, 'clf__reg_alpha': 66, 'clf__reg_lambda': 0.07825269374126022, 'clf__colsample_bytree': 0.8824606308769356, 'clf__min_child_weight': 2, 'clf__n_estimators': 127}
# {'vect__max_df': 0.7966423415434833, 'vect__min_df': 39, 'clf__max_depth': 4, 'clf__gamma': 2.0519930730300215, 'clf__reg_alpha': 66, 'clf__reg_lambda': 0.07825269374126022, 'clf__colsample_bytree': 0.8824606308769356, 'clf__min_child_weight': 2, 'clf__n_estimators': 127, 'vect__ngram_range': (1, 1)}
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 12.8079
# Function value obtained: -0.5612
# Current minimum: -0.5619
# Iteration No: 25 started. Searching for the next optimal point.
# {'vect__max_df': 0.8215566662117857, 'vect__min_df': 43, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 4.198616253735751, 'clf__reg_alpha': 77, 'clf__reg_lambda': 0.7387916892849538, 'clf__colsample_bytree': 0.8666614480446504, 'clf__min_child_weight': 0, 'clf__n_estimators': 62}
# {'vect__max_df': 0.8215566662117857, 'vect__min_df': 43, 'clf__max_depth': 3, 'clf__gamma': 4.198616253735751, 'clf__reg_alpha': 77, 'clf__reg_lambda': 0.7387916892849538, 'clf__colsample_bytree': 0.8666614480446504, 'clf__min_child_weight': 0, 'clf__n_estimators': 62, 'vect__ngram_range': (1, 1)}
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 5.4335
# Function value obtained: -0.5541
# Current minimum: -0.5619
# Iteration No: 26 started. Searching for the next optimal point.
# {'vect__max_df': 0.7400230818855962, 'vect__min_df': 41, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 4.632401117092555, 'clf__reg_alpha': 64, 'clf__reg_lambda': 0.4373308430700016, 'clf__colsample_bytree': 0.7067481124073485, 'clf__min_child_weight': 3, 'clf__n_estimators': 70}
# {'vect__max_df': 0.7400230818855962, 'vect__min_df': 41, 'clf__max_depth': 3, 'clf__gamma': 4.632401117092555, 'clf__reg_alpha': 64, 'clf__reg_lambda': 0.4373308430700016, 'clf__colsample_bytree': 0.7067481124073485, 'clf__min_child_weight': 3, 'clf__n_estimators': 70, 'vect__ngram_range': (1, 1)}
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 5.1604
# Function value obtained: -0.5569
# Current minimum: -0.5619
# Iteration No: 27 started. Searching for the next optimal point.
# {'vect__max_df': 0.8775683794840599, 'vect__min_df': 34, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 2.3451956141886203, 'clf__reg_alpha': 65, 'clf__reg_lambda': 0.7432407431374505, 'clf__colsample_bytree': 0.8290980152643268, 'clf__min_child_weight': 2, 'clf__n_estimators': 39}
# {'vect__max_df': 0.8775683794840599, 'vect__min_df': 34, 'clf__max_depth': 3, 'clf__gamma': 2.3451956141886203, 'clf__reg_alpha': 65, 'clf__reg_lambda': 0.7432407431374505, 'clf__colsample_bytree': 0.8290980152643268, 'clf__min_child_weight': 2, 'clf__n_estimators': 39, 'vect__ngram_range': (1, 1)}
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 3.6228
# Function value obtained: -0.5564
# Current minimum: -0.5619
# Iteration No: 28 started. Searching for the next optimal point.
# {'vect__max_df': 0.7566768858512838, 'vect__min_df': 39, 'ngrams': 2, 'clf__max_depth': 4, 'clf__gamma': 8.436176847489675, 'clf__reg_alpha': 71, 'clf__reg_lambda': 0.7681660900730704, 'clf__colsample_bytree': 0.9591814699237662, 'clf__min_child_weight': 0, 'clf__n_estimators': 109}
# {'vect__max_df': 0.7566768858512838, 'vect__min_df': 39, 'clf__max_depth': 4, 'clf__gamma': 8.436176847489675, 'clf__reg_alpha': 71, 'clf__reg_lambda': 0.7681660900730704, 'clf__colsample_bytree': 0.9591814699237662, 'clf__min_child_weight': 0, 'clf__n_estimators': 109, 'vect__ngram_range': (1, 2)}
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 15.4799
# Function value obtained: -0.5564
# Current minimum: -0.5619
# Iteration No: 29 started. Searching for the next optimal point.
# {'vect__max_df': 0.8352938704564739, 'vect__min_df': 29, 'ngrams': 2, 'clf__max_depth': 4, 'clf__gamma': 5.4558340230298885, 'clf__reg_alpha': 83, 'clf__reg_lambda': 0.7576618454066371, 'clf__colsample_bytree': 0.961037171987267, 'clf__min_child_weight': 1, 'clf__n_estimators': 68}
# {'vect__max_df': 0.8352938704564739, 'vect__min_df': 29, 'clf__max_depth': 4, 'clf__gamma': 5.4558340230298885, 'clf__reg_alpha': 83, 'clf__reg_lambda': 0.7576618454066371, 'clf__colsample_bytree': 0.961037171987267, 'clf__min_child_weight': 1, 'clf__n_estimators': 68, 'vect__ngram_range': (1, 2)}
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 10.4424
# Function value obtained: -0.5555
# Current minimum: -0.5619
# Iteration No: 30 started. Searching for the next optimal point.
# {'vect__max_df': 0.8053533310091171, 'vect__min_df': 40, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 4.107980241861188, 'clf__reg_alpha': 55, 'clf__reg_lambda': 0.21300983401742307, 'clf__colsample_bytree': 0.9921884523421953, 'clf__min_child_weight': 0, 'clf__n_estimators': 66}
# {'vect__max_df': 0.8053533310091171, 'vect__min_df': 40, 'clf__max_depth': 4, 'clf__gamma': 4.107980241861188, 'clf__reg_alpha': 55, 'clf__reg_lambda': 0.21300983401742307, 'clf__colsample_bytree': 0.9921884523421953, 'clf__min_child_weight': 0, 'clf__n_estimators': 66, 'vect__ngram_range': (1, 1)}
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 8.0772
# Function value obtained: -0.5609
# Current minimum: -0.5619
# Iteration No: 31 started. Searching for the next optimal point.
# {'vect__max_df': 0.8796195707559901, 'vect__min_df': 6, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 5.934303587521874, 'clf__reg_alpha': 45, 'clf__reg_lambda': 0.2754766444896513, 'clf__colsample_bytree': 0.9708158302631646, 'clf__min_child_weight': 1, 'clf__n_estimators': 151}
# {'vect__max_df': 0.8796195707559901, 'vect__min_df': 6, 'clf__max_depth': 3, 'clf__gamma': 5.934303587521874, 'clf__reg_alpha': 45, 'clf__reg_lambda': 0.2754766444896513, 'clf__colsample_bytree': 0.9708158302631646, 'clf__min_child_weight': 1, 'clf__n_estimators': 151, 'vect__ngram_range': (1, 1)}
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 14.3926
# Function value obtained: -0.5591
# Current minimum: -0.5619
# Iteration No: 32 started. Searching for the next optimal point.
# {'vect__max_df': 0.7903856725228723, 'vect__min_df': 40, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 5.402295028961733, 'clf__reg_alpha': 70, 'clf__reg_lambda': 0.6474895881801999, 'clf__colsample_bytree': 0.9543375911053013, 'clf__min_child_weight': 1, 'clf__n_estimators': 65}
# {'vect__max_df': 0.7903856725228723, 'vect__min_df': 40, 'clf__max_depth': 4, 'clf__gamma': 5.402295028961733, 'clf__reg_alpha': 70, 'clf__reg_lambda': 0.6474895881801999, 'clf__colsample_bytree': 0.9543375911053013, 'clf__min_child_weight': 1, 'clf__n_estimators': 65, 'vect__ngram_range': (1, 1)}
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 7.6033
# Function value obtained: -0.5561
# Current minimum: -0.5619
# Iteration No: 33 started. Searching for the next optimal point.
# {'vect__max_df': 0.8956283116075002, 'vect__min_df': 26, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 4.729120841897998, 'clf__reg_alpha': 55, 'clf__reg_lambda': 0.7771176987323133, 'clf__colsample_bytree': 0.8873431793436652, 'clf__min_child_weight': 0, 'clf__n_estimators': 131}
# {'vect__max_df': 0.8956283116075002, 'vect__min_df': 26, 'clf__max_depth': 3, 'clf__gamma': 4.729120841897998, 'clf__reg_alpha': 55, 'clf__reg_lambda': 0.7771176987323133, 'clf__colsample_bytree': 0.8873431793436652, 'clf__min_child_weight': 0, 'clf__n_estimators': 131, 'vect__ngram_range': (1, 1)}
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 11.1510
# Function value obtained: -0.5592
# Current minimum: -0.5619
# Iteration No: 34 started. Searching for the next optimal point.
# {'vect__max_df': 0.9075898579578658, 'vect__min_df': 36, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 4.190367146778331, 'clf__reg_alpha': 50, 'clf__reg_lambda': 0.6062890225960446, 'clf__colsample_bytree': 0.8985338813078849, 'clf__min_child_weight': 0, 'clf__n_estimators': 59}
# {'vect__max_df': 0.9075898579578658, 'vect__min_df': 36, 'clf__max_depth': 3, 'clf__gamma': 4.190367146778331, 'clf__reg_alpha': 50, 'clf__reg_lambda': 0.6062890225960446, 'clf__colsample_bytree': 0.8985338813078849, 'clf__min_child_weight': 0, 'clf__n_estimators': 59, 'vect__ngram_range': (1, 1)}
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 5.4285
# Function value obtained: -0.5584
# Current minimum: -0.5619
# Iteration No: 35 started. Searching for the next optimal point.
# {'vect__max_df': 0.7005327718448546, 'vect__min_df': 43, 'ngrams': 1, 'clf__max_depth': 5, 'clf__gamma': 3.5518989693925787, 'clf__reg_alpha': 84, 'clf__reg_lambda': 0.6365004165364357, 'clf__colsample_bytree': 0.962863872145695, 'clf__min_child_weight': 8, 'clf__n_estimators': 84}
# {'vect__max_df': 0.7005327718448546, 'vect__min_df': 43, 'clf__max_depth': 5, 'clf__gamma': 3.5518989693925787, 'clf__reg_alpha': 84, 'clf__reg_lambda': 0.6365004165364357, 'clf__colsample_bytree': 0.962863872145695, 'clf__min_child_weight': 8, 'clf__n_estimators': 84, 'vect__ngram_range': (1, 1)}
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 10.4330
# Function value obtained: -0.5592
# Current minimum: -0.5619
# Iteration No: 36 started. Searching for the next optimal point.
# {'vect__max_df': 0.8894385068755191, 'vect__min_df': 34, 'ngrams': 1, 'clf__max_depth': 8, 'clf__gamma': 3.1412513986359865, 'clf__reg_alpha': 91, 'clf__reg_lambda': 0.5849815731436206, 'clf__colsample_bytree': 0.9381395434971465, 'clf__min_child_weight': 2, 'clf__n_estimators': 101}
# {'vect__max_df': 0.8894385068755191, 'vect__min_df': 34, 'clf__max_depth': 8, 'clf__gamma': 3.1412513986359865, 'clf__reg_alpha': 91, 'clf__reg_lambda': 0.5849815731436206, 'clf__colsample_bytree': 0.9381395434971465, 'clf__min_child_weight': 2, 'clf__n_estimators': 101, 'vect__ngram_range': (1, 1)}
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 19.4827
# Function value obtained: -0.5617
# Current minimum: -0.5619
# Iteration No: 37 started. Searching for the next optimal point.
# {'vect__max_df': 0.8890793344231085, 'vect__min_df': 50, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 2.2446545963340503, 'clf__reg_alpha': 91, 'clf__reg_lambda': 0.5761761462068934, 'clf__colsample_bytree': 0.8195366906675046, 'clf__min_child_weight': 1, 'clf__n_estimators': 79}
# {'vect__max_df': 0.8890793344231085, 'vect__min_df': 50, 'clf__max_depth': 6, 'clf__gamma': 2.2446545963340503, 'clf__reg_alpha': 91, 'clf__reg_lambda': 0.5761761462068934, 'clf__colsample_bytree': 0.8195366906675046, 'clf__min_child_weight': 1, 'clf__n_estimators': 79, 'vect__ngram_range': (1, 1)}
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 10.4880
# Function value obtained: -0.5609
# Current minimum: -0.5619
# Iteration No: 38 started. Searching for the next optimal point.
# {'vect__max_df': 0.8983577039898221, 'vect__min_df': 48, 'ngrams': 1, 'clf__max_depth': 5, 'clf__gamma': 3.020729092455072, 'clf__reg_alpha': 93, 'clf__reg_lambda': 0.3011179910926058, 'clf__colsample_bytree': 0.6250305360651744, 'clf__min_child_weight': 2, 'clf__n_estimators': 287}
# {'vect__max_df': 0.8983577039898221, 'vect__min_df': 48, 'clf__max_depth': 5, 'clf__gamma': 3.020729092455072, 'clf__reg_alpha': 93, 'clf__reg_lambda': 0.3011179910926058, 'clf__colsample_bytree': 0.6250305360651744, 'clf__min_child_weight': 2, 'clf__n_estimators': 287, 'vect__ngram_range': (1, 1)}
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 25.5007
# Function value obtained: -0.5567
# Current minimum: -0.5619
# Iteration No: 39 started. Searching for the next optimal point.
# {'vect__max_df': 0.7417769434500275, 'vect__min_df': 14, 'ngrams': 1, 'clf__max_depth': 7, 'clf__gamma': 2.596081658135039, 'clf__reg_alpha': 101, 'clf__reg_lambda': 0.19094607570231842, 'clf__colsample_bytree': 0.9268065286480192, 'clf__min_child_weight': 0, 'clf__n_estimators': 102}
# {'vect__max_df': 0.7417769434500275, 'vect__min_df': 14, 'clf__max_depth': 7, 'clf__gamma': 2.596081658135039, 'clf__reg_alpha': 101, 'clf__reg_lambda': 0.19094607570231842, 'clf__colsample_bytree': 0.9268065286480192, 'clf__min_child_weight': 0, 'clf__n_estimators': 102, 'vect__ngram_range': (1, 1)}
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 19.4287
# Function value obtained: -0.5606
# Current minimum: -0.5619
# Iteration No: 40 started. Searching for the next optimal point.
# {'vect__max_df': 0.9430100009899415, 'vect__min_df': 15, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 3.0613551130385415, 'clf__reg_alpha': 86, 'clf__reg_lambda': 0.5335042071081744, 'clf__colsample_bytree': 0.9002865403497131, 'clf__min_child_weight': 2, 'clf__n_estimators': 98}
# {'vect__max_df': 0.9430100009899415, 'vect__min_df': 15, 'clf__max_depth': 4, 'clf__gamma': 3.0613551130385415, 'clf__reg_alpha': 86, 'clf__reg_lambda': 0.5335042071081744, 'clf__colsample_bytree': 0.9002865403497131, 'clf__min_child_weight': 2, 'clf__n_estimators': 98, 'vect__ngram_range': (1, 1)}
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 10.9476
# Function value obtained: -0.5562
# Current minimum: -0.5619
# Iteration No: 41 started. Searching for the next optimal point.
# {'vect__max_df': 0.8881583345083532, 'vect__min_df': 12, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 3.3275667176689674, 'clf__reg_alpha': 174, 'clf__reg_lambda': 0.9018830150092993, 'clf__colsample_bytree': 0.9645479558500107, 'clf__min_child_weight': 0, 'clf__n_estimators': 101}
# {'vect__max_df': 0.8881583345083532, 'vect__min_df': 12, 'clf__max_depth': 6, 'clf__gamma': 3.3275667176689674, 'clf__reg_alpha': 174, 'clf__reg_lambda': 0.9018830150092993, 'clf__colsample_bytree': 0.9645479558500107, 'clf__min_child_weight': 0, 'clf__n_estimators': 101, 'vect__ngram_range': (1, 1)}
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 16.8900
# Function value obtained: -0.5554
# Current minimum: -0.5619
# Iteration No: 42 started. Searching for the next optimal point.
# {'vect__max_df': 0.8953512701736762, 'vect__min_df': 23, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 1.5460637089008387, 'clf__reg_alpha': 96, 'clf__reg_lambda': 0.4693482412410014, 'clf__colsample_bytree': 0.9394260950690269, 'clf__min_child_weight': 2, 'clf__n_estimators': 103}
# {'vect__max_df': 0.8953512701736762, 'vect__min_df': 23, 'clf__max_depth': 6, 'clf__gamma': 1.5460637089008387, 'clf__reg_alpha': 96, 'clf__reg_lambda': 0.4693482412410014, 'clf__colsample_bytree': 0.9394260950690269, 'clf__min_child_weight': 2, 'clf__n_estimators': 103, 'vect__ngram_range': (1, 1)}
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 13.4770
# Function value obtained: -0.5612
# Current minimum: -0.5619
# Iteration No: 43 started. Searching for the next optimal point.
# {'vect__max_df': 0.8986513165225409, 'vect__min_df': 35, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 3.9243913189389352, 'clf__reg_alpha': 99, 'clf__reg_lambda': 0.38639578706294453, 'clf__colsample_bytree': 0.7745314605363827, 'clf__min_child_weight': 5, 'clf__n_estimators': 83}
# {'vect__max_df': 0.8986513165225409, 'vect__min_df': 35, 'clf__max_depth': 6, 'clf__gamma': 3.9243913189389352, 'clf__reg_alpha': 99, 'clf__reg_lambda': 0.38639578706294453, 'clf__colsample_bytree': 0.7745314605363827, 'clf__min_child_weight': 5, 'clf__n_estimators': 83, 'vect__ngram_range': (1, 1)}
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 10.7049
# Function value obtained: -0.5587
# Current minimum: -0.5619
# Iteration No: 44 started. Searching for the next optimal point.
# {'vect__max_df': 0.8860231253934551, 'vect__min_df': 13, 'ngrams': 1, 'clf__max_depth': 7, 'clf__gamma': 2.1389362922973376, 'clf__reg_alpha': 79, 'clf__reg_lambda': 0.6477268678416398, 'clf__colsample_bytree': 0.921001480126605, 'clf__min_child_weight': 0, 'clf__n_estimators': 53}
# {'vect__max_df': 0.8860231253934551, 'vect__min_df': 13, 'clf__max_depth': 7, 'clf__gamma': 2.1389362922973376, 'clf__reg_alpha': 79, 'clf__reg_lambda': 0.6477268678416398, 'clf__colsample_bytree': 0.921001480126605, 'clf__min_child_weight': 0, 'clf__n_estimators': 53, 'vect__ngram_range': (1, 1)}
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 10.6673
# Function value obtained: -0.5614
# Current minimum: -0.5619
# Iteration No: 45 started. Searching for the next optimal point.
# {'vect__max_df': 0.7286642788935723, 'vect__min_df': 41, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 2.8881338917178687, 'clf__reg_alpha': 104, 'clf__reg_lambda': 0.653481037158875, 'clf__colsample_bytree': 0.9988397163487226, 'clf__min_child_weight': 0, 'clf__n_estimators': 92}
# {'vect__max_df': 0.7286642788935723, 'vect__min_df': 41, 'clf__max_depth': 6, 'clf__gamma': 2.8881338917178687, 'clf__reg_alpha': 104, 'clf__reg_lambda': 0.653481037158875, 'clf__colsample_bytree': 0.9988397163487226, 'clf__min_child_weight': 0, 'clf__n_estimators': 92, 'vect__ngram_range': (1, 1)}
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 15.4883
# Function value obtained: -0.5592
# Current minimum: -0.5619
# Iteration No: 46 started. Searching for the next optimal point.
# {'vect__max_df': 0.7614422369877787, 'vect__min_df': 23, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 1.931254934282076, 'clf__reg_alpha': 139, 'clf__reg_lambda': 0.2750943047195677, 'clf__colsample_bytree': 0.9828164339556797, 'clf__min_child_weight': 0, 'clf__n_estimators': 68}
# {'vect__max_df': 0.7614422369877787, 'vect__min_df': 23, 'clf__max_depth': 4, 'clf__gamma': 1.931254934282076, 'clf__reg_alpha': 139, 'clf__reg_lambda': 0.2750943047195677, 'clf__colsample_bytree': 0.9828164339556797, 'clf__min_child_weight': 0, 'clf__n_estimators': 68, 'vect__ngram_range': (1, 1)}
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 8.3626
# Function value obtained: -0.5545
# Current minimum: -0.5619
# Iteration No: 47 started. Searching for the next optimal point.
# {'vect__max_df': 0.9189548264342691, 'vect__min_df': 44, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 1.4502428292001213, 'clf__reg_alpha': 123, 'clf__reg_lambda': 0.29379302477212627, 'clf__colsample_bytree': 0.9142208270569983, 'clf__min_child_weight': 4, 'clf__n_estimators': 107}
# {'vect__max_df': 0.9189548264342691, 'vect__min_df': 44, 'clf__max_depth': 6, 'clf__gamma': 1.4502428292001213, 'clf__reg_alpha': 123, 'clf__reg_lambda': 0.29379302477212627, 'clf__colsample_bytree': 0.9142208270569983, 'clf__min_child_weight': 4, 'clf__n_estimators': 107, 'vect__ngram_range': (1, 1)}
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 11.9989
# Function value obtained: -0.5579
# Current minimum: -0.5619
# Iteration No: 48 started. Searching for the next optimal point.
# {'vect__max_df': 0.8840475887207409, 'vect__min_df': 14, 'ngrams': 1, 'clf__max_depth': 6, 'clf__gamma': 3.654884152303285, 'clf__reg_alpha': 93, 'clf__reg_lambda': 0.9488674180276528, 'clf__colsample_bytree': 0.8363375333687495, 'clf__min_child_weight': 2, 'clf__n_estimators': 284}
# {'vect__max_df': 0.8840475887207409, 'vect__min_df': 14, 'clf__max_depth': 6, 'clf__gamma': 3.654884152303285, 'clf__reg_alpha': 93, 'clf__reg_lambda': 0.9488674180276528, 'clf__colsample_bytree': 0.8363375333687495, 'clf__min_child_weight': 2, 'clf__n_estimators': 284, 'vect__ngram_range': (1, 1)}
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 42.2461
# Function value obtained: -0.5586
# Current minimum: -0.5619
# Iteration No: 49 started. Searching for the next optimal point.
# {'vect__max_df': 0.7336782521289521, 'vect__min_df': 50, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 2.7557752594354032, 'clf__reg_alpha': 49, 'clf__reg_lambda': 0.6697791637942924, 'clf__colsample_bytree': 0.8488930536602581, 'clf__min_child_weight': 0, 'clf__n_estimators': 146}
# {'vect__max_df': 0.7336782521289521, 'vect__min_df': 50, 'clf__max_depth': 4, 'clf__gamma': 2.7557752594354032, 'clf__reg_alpha': 49, 'clf__reg_lambda': 0.6697791637942924, 'clf__colsample_bytree': 0.8488930536602581, 'clf__min_child_weight': 0, 'clf__n_estimators': 146, 'vect__ngram_range': (1, 1)}
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 14.9114
# Function value obtained: -0.5614
# Current minimum: -0.5619
# Iteration No: 50 started. Searching for the next optimal point.
# {'vect__max_df': 0.8348697093074366, 'vect__min_df': 49, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 1.2188091143518553, 'clf__reg_alpha': 83, 'clf__reg_lambda': 0.5937900261888055, 'clf__colsample_bytree': 0.6929378950153573, 'clf__min_child_weight': 0, 'clf__n_estimators': 151}
# {'vect__max_df': 0.8348697093074366, 'vect__min_df': 49, 'clf__max_depth': 4, 'clf__gamma': 1.2188091143518553, 'clf__reg_alpha': 83, 'clf__reg_lambda': 0.5937900261888055, 'clf__colsample_bytree': 0.6929378950153573, 'clf__min_child_weight': 0, 'clf__n_estimators': 151, 'vect__ngram_range': (1, 1)}
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 11.0828
# Function value obtained: -0.5595
# Current minimum: -0.5619
# Iteration No: 51 started. Searching for the next optimal point.
# {'vect__max_df': 0.7621306418267574, 'vect__min_df': 48, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 8.462415789059765, 'clf__reg_alpha': 52, 'clf__reg_lambda': 0.6305558555257817, 'clf__colsample_bytree': 0.8971798863168374, 'clf__min_child_weight': 1, 'clf__n_estimators': 246}
# {'vect__max_df': 0.7621306418267574, 'vect__min_df': 48, 'clf__max_depth': 4, 'clf__gamma': 8.462415789059765, 'clf__reg_alpha': 52, 'clf__reg_lambda': 0.6305558555257817, 'clf__colsample_bytree': 0.8971798863168374, 'clf__min_child_weight': 1, 'clf__n_estimators': 246, 'vect__ngram_range': (1, 1)}
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 25.5293
# Function value obtained: -0.5571
# Current minimum: -0.5619
# Iteration No: 52 started. Searching for the next optimal point.
# {'vect__max_df': 0.926580752579174, 'vect__min_df': 29, 'ngrams': 1, 'clf__max_depth': 5, 'clf__gamma': 2.2884896769486955, 'clf__reg_alpha': 96, 'clf__reg_lambda': 0.1445753168339006, 'clf__colsample_bytree': 0.9677847172870828, 'clf__min_child_weight': 0, 'clf__n_estimators': 59}
# {'vect__max_df': 0.926580752579174, 'vect__min_df': 29, 'clf__max_depth': 5, 'clf__gamma': 2.2884896769486955, 'clf__reg_alpha': 96, 'clf__reg_lambda': 0.1445753168339006, 'clf__colsample_bytree': 0.9677847172870828, 'clf__min_child_weight': 0, 'clf__n_estimators': 59, 'vect__ngram_range': (1, 1)}
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 8.8378
# Function value obtained: -0.5586
# Current minimum: -0.5619
# Iteration No: 53 started. Searching for the next optimal point.
# {'vect__max_df': 0.7536317118979649, 'vect__min_df': 41, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 2.1029848121710852, 'clf__reg_alpha': 94, 'clf__reg_lambda': 0.12312781969839096, 'clf__colsample_bytree': 0.9078988677221924, 'clf__min_child_weight': 7, 'clf__n_estimators': 165}
# {'vect__max_df': 0.7536317118979649, 'vect__min_df': 41, 'clf__max_depth': 4, 'clf__gamma': 2.1029848121710852, 'clf__reg_alpha': 94, 'clf__reg_lambda': 0.12312781969839096, 'clf__colsample_bytree': 0.9078988677221924, 'clf__min_child_weight': 7, 'clf__n_estimators': 165, 'vect__ngram_range': (1, 1)}
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 15.7635
# Function value obtained: -0.5581
# Current minimum: -0.5619
# Iteration No: 54 started. Searching for the next optimal point.
# {'vect__max_df': 0.8193823509851492, 'vect__min_df': 29, 'ngrams': 2, 'clf__max_depth': 9, 'clf__gamma': 3.1866545916918008, 'clf__reg_alpha': 83, 'clf__reg_lambda': 0.7008419591515533, 'clf__colsample_bytree': 0.8557818857371005, 'clf__min_child_weight': 0, 'clf__n_estimators': 133}
# {'vect__max_df': 0.8193823509851492, 'vect__min_df': 29, 'clf__max_depth': 9, 'clf__gamma': 3.1866545916918008, 'clf__reg_alpha': 83, 'clf__reg_lambda': 0.7008419591515533, 'clf__colsample_bytree': 0.8557818857371005, 'clf__min_child_weight': 0, 'clf__n_estimators': 133, 'vect__ngram_range': (1, 2)}
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 36.4577
# Function value obtained: -0.5600
# Current minimum: -0.5619
# Iteration No: 55 started. Searching for the next optimal point.
# {'vect__max_df': 0.8317519590402664, 'vect__min_df': 30, 'ngrams': 2, 'clf__max_depth': 4, 'clf__gamma': 3.9133848765217434, 'clf__reg_alpha': 66, 'clf__reg_lambda': 0.08890481372733307, 'clf__colsample_bytree': 0.6421934560847761, 'clf__min_child_weight': 0, 'clf__n_estimators': 64}
# {'vect__max_df': 0.8317519590402664, 'vect__min_df': 30, 'clf__max_depth': 4, 'clf__gamma': 3.9133848765217434, 'clf__reg_alpha': 66, 'clf__reg_lambda': 0.08890481372733307, 'clf__colsample_bytree': 0.6421934560847761, 'clf__min_child_weight': 0, 'clf__n_estimators': 64, 'vect__ngram_range': (1, 2)}
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 7.7125
# Function value obtained: -0.5594
# Current minimum: -0.5619
# Iteration No: 56 started. Searching for the next optimal point.
# {'vect__max_df': 0.8272328180412019, 'vect__min_df': 46, 'ngrams': 1, 'clf__max_depth': 3, 'clf__gamma': 1.9771753518438617, 'clf__reg_alpha': 82, 'clf__reg_lambda': 0.34542562799218685, 'clf__colsample_bytree': 0.9068387213537451, 'clf__min_child_weight': 1, 'clf__n_estimators': 269}
# {'vect__max_df': 0.8272328180412019, 'vect__min_df': 46, 'clf__max_depth': 3, 'clf__gamma': 1.9771753518438617, 'clf__reg_alpha': 82, 'clf__reg_lambda': 0.34542562799218685, 'clf__colsample_bytree': 0.9068387213537451, 'clf__min_child_weight': 1, 'clf__n_estimators': 269, 'vect__ngram_range': (1, 1)}
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 21.5116
# Function value obtained: -0.5580
# Current minimum: -0.5619
# Iteration No: 57 started. Searching for the next optimal point.
# {'vect__max_df': 0.9210615599512226, 'vect__min_df': 13, 'ngrams': 1, 'clf__max_depth': 24, 'clf__gamma': 7.097162237384163, 'clf__reg_alpha': 96, 'clf__reg_lambda': 0.44690287956309993, 'clf__colsample_bytree': 0.8588208471635025, 'clf__min_child_weight': 2, 'clf__n_estimators': 60}
# {'vect__max_df': 0.9210615599512226, 'vect__min_df': 13, 'clf__max_depth': 24, 'clf__gamma': 7.097162237384163, 'clf__reg_alpha': 96, 'clf__reg_lambda': 0.44690287956309993, 'clf__colsample_bytree': 0.8588208471635025, 'clf__min_child_weight': 2, 'clf__n_estimators': 60, 'vect__ngram_range': (1, 1)}
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 31.9838
# Function value obtained: -0.5590
# Current minimum: -0.5619
# Iteration No: 58 started. Searching for the next optimal point.
# {'vect__max_df': 0.7151182252241978, 'vect__min_df': 40, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 5.368976826028904, 'clf__reg_alpha': 40, 'clf__reg_lambda': 0.6089256355847444, 'clf__colsample_bytree': 0.7125412623794187, 'clf__min_child_weight': 3, 'clf__n_estimators': 56}
# {'vect__max_df': 0.7151182252241978, 'vect__min_df': 40, 'clf__max_depth': 4, 'clf__gamma': 5.368976826028904, 'clf__reg_alpha': 40, 'clf__reg_lambda': 0.6089256355847444, 'clf__colsample_bytree': 0.7125412623794187, 'clf__min_child_weight': 3, 'clf__n_estimators': 56, 'vect__ngram_range': (1, 1)}
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 5.3768
# Function value obtained: -0.5609
# Current minimum: -0.5619
# Iteration No: 59 started. Searching for the next optimal point.
# {'vect__max_df': 0.7895686707075872, 'vect__min_df': 29, 'ngrams': 2, 'clf__max_depth': 4, 'clf__gamma': 4.664689003512619, 'clf__reg_alpha': 52, 'clf__reg_lambda': 0.9221526470677982, 'clf__colsample_bytree': 0.8233319005784383, 'clf__min_child_weight': 7, 'clf__n_estimators': 38}
# {'vect__max_df': 0.7895686707075872, 'vect__min_df': 29, 'clf__max_depth': 4, 'clf__gamma': 4.664689003512619, 'clf__reg_alpha': 52, 'clf__reg_lambda': 0.9221526470677982, 'clf__colsample_bytree': 0.8233319005784383, 'clf__min_child_weight': 7, 'clf__n_estimators': 38, 'vect__ngram_range': (1, 2)}
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 5.3210
# Function value obtained: -0.5572
# Current minimum: -0.5619
# Iteration No: 60 started. Searching for the next optimal point.
# {'vect__max_df': 0.7473250540791945, 'vect__min_df': 23, 'ngrams': 1, 'clf__max_depth': 4, 'clf__gamma': 7.100818578960666, 'clf__reg_alpha': 49, 'clf__reg_lambda': 0.74537383240203, 'clf__colsample_bytree': 0.5648982627673192, 'clf__min_child_weight': 0, 'clf__n_estimators': 183}
# {'vect__max_df': 0.7473250540791945, 'vect__min_df': 23, 'clf__max_depth': 4, 'clf__gamma': 7.100818578960666, 'clf__reg_alpha': 49, 'clf__reg_lambda': 0.74537383240203, 'clf__colsample_bytree': 0.5648982627673192, 'clf__min_child_weight': 0, 'clf__n_estimators': 183, 'vect__ngram_range': (1, 1)}
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 14.8736
# Function value obtained: -0.5584
# Current minimum: -0.5619
# Iteration No: 61 started. Searching for the next optimal point.
# {'vect__max_df': 0.9410559590498487, 'vect__min_df': 34, 'ngrams': 1, 'clf__max_depth': 9, 'clf__gamma': 6.040951522046204, 'clf__reg_alpha': 93, 'clf__reg_lambda': 0.6117486835929001, 'clf__colsample_bytree': 0.706285666024971, 'clf__min_child_weight': 2, 'clf__n_estimators': 43}
# ...
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 282.2062
# Function value obtained: -0.7182
# Current minimum: -0.7216
# Iteration No: 69 started. Searching for the next optimal point.
# {'vect__max_df': 0.8916394249820174, 'vect__min_df': 25, 'ngrams': 2, 'clf__max_depth': 18, 'clf__gamma': 7.695504635563855, 'clf__reg_alpha': 57, 'clf__reg_lambda': 0.0005545273021742015, 'clf__colsample_bytree': 0.5536297155978449, 'clf__min_child_weight': 4, 'clf__n_estimators': 232}
# {'vect__max_df': 0.8916394249820174, 'vect__min_df': 25, 'clf__max_depth': 18, 'clf__gamma': 7.695504635563855, 'clf__reg_alpha': 57, 'clf__reg_lambda': 0.0005545273021742015, 'clf__colsample_bytree': 0.5536297155978449, 'clf__min_child_weight': 4, 'clf__n_estimators': 232, 'vect__ngram_range': (1, 2)}
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 277.1801
# Function value obtained: -0.7199
# Current minimum: -0.7216
# Iteration No: 70 started. Searching for the next optimal point.
# {'vect__max_df': 0.8002299152028434, 'vect__min_df': 48, 'ngrams': 2, 'clf__max_depth': 25, 'clf__gamma': 7.619933949252034, 'clf__reg_alpha': 139, 'clf__reg_lambda': 0.15729604215965068, 'clf__colsample_bytree': 0.951721374114196, 'clf__min_child_weight': 2, 'clf__n_estimators': 284}
# {'vect__max_df': 0.8002299152028434, 'vect__min_df': 48, 'clf__max_depth': 25, 'clf__gamma': 7.619933949252034, 'clf__reg_alpha': 139, 'clf__reg_lambda': 0.15729604215965068, 'clf__colsample_bytree': 0.951721374114196, 'clf__min_child_weight': 2, 'clf__n_estimators': 284, 'vect__ngram_range': (1, 2)}
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 676.2756
# Function value obtained: -0.7187
# Current minimum: -0.7216
#           fun: -0.7215784368778396
#     func_vals: array([-0.71900046, -0.71808158, -0.71792843, -0.71943438, -0.71884731,
#        -0.71795395, -0.71871969, -0.72027669, -0.71754556, -0.71874521,
#        -0.71951095, -0.71843892, -0.72022564, -0.71900046, -0.72040431,
#        -0.71759661, -0.72002144, -0.71989382, -0.71777528, -0.71979172,
#        -0.71900046, -0.71984277, -0.71900046, -0.71938333, -0.71907703,
#        -0.7192557 , -0.71741794, -0.71803053, -0.71854102, -0.7192557 ,
#        -0.71805605, -0.72048088, -0.71928123, -0.71938333, -0.71833682,
#        -0.72037878, -0.72027669, -0.71905151, -0.72020011, -0.71917913,
#        -0.72055746, -0.72053193, -0.7183113 , -0.72157844, -0.71920466,
#        -0.72055746, -0.72076165, -0.72002144, -0.71953647, -0.72073613,
#        -0.71920466, -0.71772423, -0.71915361, -0.71912808, -0.718005  ,
#        -0.72007249, -0.7183113 , -0.72014906, -0.71953647, -0.7194599 ,
#        -0.7194599 , -0.72042983, -0.71866864, -0.71833682, -0.72042983,
#        -0.72002144, -0.72014906, -0.71823472, -0.71989382, -0.71874521])
#        models: [ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396), ExtraTreesRegressor(min_samples_leaf=3, n_estimators=100,
#                     random_state=209652396)]
#  random_state: RandomState(MT19937) at 0x7FF10019B8D0
#         space: Space([Real(low=0.7, high=0.95, prior='uniform', transform='identity'),
#        Integer(low=5, high=50, prior='uniform', transform='identity'),
#        Integer(low=1, high=2, prior='uniform', transform='identity'),
#        Integer(low=3, high=25, prior='uniform', transform='identity'),
#        Real(low=1, high=9, prior='uniform', transform='identity'),
#        Integer(low=40, high=180, prior='uniform', transform='identity'),
#        Real(low=0, high=1, prior='uniform', transform='identity'),
#        Real(low=0.5, high=1, prior='uniform', transform='identity'),
#        Integer(low=0, high=10, prior='uniform', transform='identity'),
#        Integer(low=30, high=300, prior='uniform', transform='identity')])
#         specs: {'args': {'func': <function train_xgb_model.<locals>.objective at 0x7ff121366170>, 'dimensions': [Real(low=0.7, high=0.95, prior='uniform', transform='identity'), Integer(low=5, high=50, prior='uniform', transform='identity'), Integer(low=1, high=2, prior='uniform', transform='identity'), Integer(low=3, high=25, prior='uniform', transform='identity'), Real(low=1, high=9, prior='uniform', transform='identity'), Integer(low=40, high=180, prior='uniform', transform='identity'), Real(low=0, high=1, prior='uniform', transform='identity'), Real(low=0.5, high=1, prior='uniform', transform='identity'), Integer(low=0, high=10, prior='uniform', transform='identity'), Integer(low=30, high=300, prior='uniform', transform='identity')], 'base_estimator': 'ET', 'n_calls': 70, 'n_random_starts': None, 'n_initial_points': 10, 'initial_point_generator': 'random', 'acq_func': 'EI', 'acq_optimizer': 'sampling', 'x0': None, 'y0': None, 'random_state': 0, 'verbose': True, 'callback': None, 'n_points': 10000, 'n_restarts_optimizer': 5, 'xi': 0.01, 'kappa': 1.96, 'n_jobs': 1, 'model_queue_size': None}, 'function': 'base_minimize'}
#             x: [0.801616858093897, 43, 2, 25, 2.8634262220789792, 145, 0.11096807284681923, 0.898231466262707, 6, 183]
#       x_iters: [[0.8482111545562545, 5, 2, 6, 7.778013910273005, 61, 0.38438170729269994, 0.6487673032722362, 8, 118], [0.7681640736450283, 6, 1, 10, 5.231159358023237, 128, 0.39278479610082984, 0.9180393817686889, 8, 295], [0.8620429680127992, 21, 2, 8, 7.225254007598806, 122, 0.4736080452737106, 0.9004553759898222, 3, 177], [0.7295686064672333, 37, 2, 12, 5.298985835592086, 72, 0.5218483217500718, 0.7073309699952619, 3, 213], [0.7541375886060929, 5, 1, 7, 5.941083976607017, 78, 0.2223213882515877, 0.693244490562931, 4, 135], [0.8124874974778069, 36, 1, 4, 6.58104956741812, 97, 0.6667667154456678, 0.8353189348090797, 2, 121], [0.8876715353046141, 40, 2, 15, 5.561574163343038, 124, 0.6342740579573352, 0.9794746343122602, 4, 161], [0.948824891919472, 45, 1, 18, 4.797580018307304, 63, 0.3380076148388918, 0.8373761611295104, 0, 99], [0.7491455904200134, 5, 2, 8, 1.1085730848968787, 153, 0.8379449074988041, 0.5480492039469815, 3, 128], [0.827406094179975, 44, 2, 12, 1.15990132327007, 178, 0.28280696257640964, 0.5600982806065845, 7, 217], [0.7279949516962158, 46, 1, 6, 8.268162869785263, 45, 0.9453470888916861, 0.853449017728333, 1, 73], [0.8196696735100146, 45, 1, 7, 4.640657562270927, 103, 0.7812857510854165, 0.9945532454065997, 1, 120], [0.8625198955398626, 20, 2, 8, 3.3749523132974386, 50, 0.6234872888982677, 0.8106775979980763, 1, 243], [0.869037163552754, 16, 2, 9, 5.0618470745038815, 78, 0.9185669510809247, 0.8672073612595744, 2, 216], [0.9168849574532536, 22, 2, 24, 2.500718784047479, 106, 0.9227099708789359, 0.6849667325007857, 1, 79], [0.9390393349943812, 29, 2, 6, 2.540691666474768, 119, 0.23661886989518394, 0.5720326412889554, 0, 81], [0.9448210401957339, 18, 1, 18, 2.965468642245647, 91, 0.8334192148742626, 0.529059172976491, 1, 135], [0.9237909748829739, 40, 2, 25, 1.0862404297543504, 157, 0.3182828940102222, 0.5900721834578382, 1, 89], [0.9295843533251551, 11, 2, 12, 2.6286108247594826, 151, 0.38491392084302356, 0.5459857218584794, 0, 69], [0.933427415839816, 11, 2, 22, 1.3515248042159413, 134, 0.7966015819217523, 0.5106131026414013, 1, 76], [0.7642130196104332, 8, 1, 17, 1.7866474480191716, 152, 0.9932179343190601, 0.9046751354948763, 0, 84], [0.7633272035877058, 25, 2, 19, 2.917055115073866, 107, 0.01895735855027925, 0.679451004967263, 0, 123], [0.920999335089068, 6, 2, 14, 1.987106855907576, 138, 0.8757277441815284, 0.6663304693207627, 1, 116], [0.8657395840922868, 30, 2, 15, 1.3233122433062174, 100, 0.5949075879467026, 0.5080706841686089, 0, 118], [0.8524521053920078, 28, 2, 7, 2.755475234002325, 87, 0.5886200182218264, 0.6445297254854314, 0, 243], [0.9319862364503287, 5, 1, 20, 3.77686466830395, 179, 0.6963865417020526, 0.9168562368434914, 7, 72], [0.9191258854635447, 42, 2, 18, 7.898375143758191, 137, 0.1134267289099429, 0.526248079498711, 0, 97], [0.7647957484408342, 46, 2, 22, 6.173490964163841, 170, 0.1036383993264958, 0.5637848963734142, 0, 136], [0.9401650730757245, 28, 1, 22, 7.762315220361274, 107, 0.400671725652193, 0.6913849042863716, 1, 115], [0.8882050778114176, 27, 2, 24, 5.100999786013576, 128, 0.22510418442669228, 0.5622472643695883, 2, 73], [0.7417818460609705, 41, 2, 25, 8.52647472315782, 126, 0.8813879769758063, 0.7932790877505731, 6, 31], [0.9019530907055524, 40, 2, 17, 7.2204308231798855, 43, 0.9491732654553262, 0.9028354598474899, 0, 170], [0.9040828683209041, 48, 2, 21, 6.9117426526862475, 89, 0.8111965233883092, 0.9351873037474255, 0, 290], [0.9299834727572506, 19, 2, 21, 8.588114850363855, 73, 0.04641814215878149, 0.712652559585168, 1, 97], [0.8974910416959262, 48, 2, 18, 8.039590902017368, 101, 0.9839021417880869, 0.5907622437991593, 0, 106], [0.9223770477888247, 37, 1, 24, 1.6441495039601977, 165, 0.25526149915731694, 0.5673308110842569, 0, 143], [0.9212347642892796, 43, 2, 17, 2.158546470347048, 122, 0.22815644596895518, 0.5434243221551289, 0, 261], [0.9253933353499099, 45, 1, 23, 4.115673725213928, 131, 0.530412608795838, 0.5029321903034749, 0, 202], [0.9402491342888677, 11, 2, 4, 3.5 ...
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:106: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/max/anaconda3/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:109: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
